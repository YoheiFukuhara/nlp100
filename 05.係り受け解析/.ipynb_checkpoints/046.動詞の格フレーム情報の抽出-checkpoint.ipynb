# %% [markdown]
# 45のプログラムを改変し，述語と格パターンに続けて項（述語に係っている文節そのもの）をタブ区切り形式で出力せよ．45の仕様に加えて，以下の仕様を満たすようにせよ．
#
# 項は述語に係っている文節の単語列とする（末尾の助詞を取り除く必要はない）
# 述語に係る文節が複数あるときは，助詞と同一の基準・順序でスペース区切りで並べる
# 「吾輩はここで始めて人間というものを見た」という例文（neko.txt.cabochaの8文目）を考える． この文は「始める」と「見る」の２つの動詞を含み，「始める」に係る文節は「ここで」，「見る」に係る文節は「吾輩は」と「ものを」と解析された場合は，次のような出力になるはずである．
#
# 始める  で      ここで
# 見る    は を   吾輩は ものを

# %%
import re

class Morph:
    def __init__(self, surface, base, pos, pos1):
        self.surface = surface # 表層形(surface)
        self.base    = base    # 基本形(base)
        self.pos     = pos     # 品詞(pos)
        self.pos1    = pos1    # 品詞細分類1(pos1)
        
    def __str__(self):
        '''オブジェクトの文字列表現'''
        return 'surface[{}]\tbase[{}]\tpos[{}]\tpos1[{}]'\
            .format(self.surface, self.base, self.pos, self.pos1)

# %%
class Chunk:
    def __init__(self):
        '''初期化'''
        self.morphs = []
        self.srcs   = []   # 係り元文節インデックス番号のリスト
        self.dst    = -1   # 係り先文節インデックス番号(初期値:-1, 係り先がない場合は-1のまま)
        
    def __str__(self):
        '''オブジェクトの文字列表現'''
        surface = ''
        for morph in self.morphs:
            surface += morph.surface
        return '{}\tsrcs{}\tdst[{}]'.format(surface, self.srcs, self.dst)
    
    def output_surface_wo_pct(self):
        surface = ''
#        pos_ok  = False
        for morph in self.morphs:
#            if morph.pos == pos:
#                pos_ok = True
            if morph.pos != '記号':
                surface += morph.surface
                #print(pos_ok)
#        if pos_ok == False:
#            return ''
#        else:
        return surface

# %%
def neko_lines():
    with open('./neko.txt.cabocha3', encoding='utf-8') as neko_cabocha:
    
        chunks = dict()     # idxをkeyにChunkを格納
        
        for line in neko_cabocha:
            if line[:3] == 'EOS':
                
                # Chunkのリストを返す
                if len(chunks) > 0:

                    # chunksをkeyでソートし、valueのみ取り出し
                    sorted_tuple = sorted(chunks.items(), key=lambda x: x[0])
                    yield list(zip(*sorted_tuple))[1]  #[1]がリストのvalue部分
                    chunks.clear()

                else:
                    yield []
                    
            # 先頭が*の行は係り受け解析結果なので、Chunkを作成
            elif line[0] == '*':

                # Chunkのインデックス番号と係り先のインデックス番号取得
                cols = re.split('\s|D', line)
                idx = int(cols[1]) # Chunkのインデックス番号
                dst = int(cols[2]) # 係り先文節インデックス番号

                # Chunkを生成（なければ）し、係り先のインデックス番号セット
                if idx not in chunks:
                    chunks[idx] = Chunk()
                chunks[idx].dst = dst

                # 係り先のChunkを生成（なければ）し、係り元インデックス番号追加
                if dst != -1:
                    if dst not in chunks:
                        chunks[dst] = Chunk()
                    chunks[dst].srcs.append(idx) # 係り元は複数あるのでappend
                    
            else:
                
                #タブとカンマで分割
                cols = re.split('\t|,', line)

                chunks[idx].morphs.append(Morph(
                        cols[0],    # 表層形(surface)
                        cols[7],    # 基本形(base)
                        cols[1],    # 品詞(pos)
                        cols[2]     # 品詞細分類1(pos1)
                    ))
        #print('stop')
        #raise StopIteration

# %%
def output_verb_with_joshi(chunk):
    # 動詞のみループ
    for verb in chunk.morphs:
        if verb.pos == '動詞':
            joshi_list = []

            # 係り元ループ
            for src in chunk.srcs:
                
                last_joshi = ''
                sentence = ''

                # 係り元の助詞のみループ
                for source in chunks[src].morphs:
                    sentence = sentence + source.surface
                    if source.pos == '助詞':
                        last_joshi = source.base  #退避
                
                # 助詞があったら追加
                if last_joshi != '':
                    joshi_list.append([last_joshi, chunks[src].output_surface_wo_pct()])

            # ファイル出力
            if len(joshi_list) > 0:
                joshi_list.sort()
                print(joshi_list)
#                unique_joshi = sorted(list(set(joshi_list)))  #ソート(重複削除はしない)
#                out_file.write('{}\t{} {}\n'.format(verb.base, ' '.join(joshi_list[0]), ' '.join(joshi_list[1])) )
                out_file.write('{}\t{}\n'.format(verb.base, ' '.join(joshi_list[0])) )
            
            # 動詞は1形態素につき最左のみなので１つ目でbreak
            break

# %%
# 結果ファイル作成
with open('./046_result.txt', mode='w') as out_file:

    # 1文ずつリスト作成
    for chunks in neko_lines():

        # 1文
        for chunk in chunks:
            # 動詞の各パターンを抽出して出力
            output_verb_with_joshi(chunk)
# Out:
# [['で', 'どこで']]
# [['か', '生れたか'], ['が', '見当が']]
# [['で', '所で']]
# [['て', '泣いて'], ['は', 'いた事だけは']]
# [['で', 'ここで']]
# [['は', '吾輩は'], ['を', 'ものを']]
# [['で', 'あとで']]
# [['を', '我々を']]
# [['て', '捕えて']]
# [['て', '煮て']]
# [['から', 'なかったから']]
# [['に', '掌に']]
# [['て', '載せられて'], ['と', 'スーと']]
# [['が', '感じが']]
# [['で', '上で']]
# [['て', '落ちついて'], ['を', '顔を']]
# [['の', 'ものの']]
# [['と', 'ものだと']]
# [['が', '感じが'], ['でも', '今でも']]
# [['をもって', '第一毛をもって']]
# [['が', '顔が']]
# [['も', '猫にも']]
# [['も', '一度も']]
# [['が', '真中が']]
# [['から', '中から'], ['を', 'ぷうぷうと煙を']]
# [['て', '咽せぽくて']]
# [['の', '人間の']]
# [['は', '事は']]
# [['で', '裏で'], ['に', '心持に']]
# [['て', '坐って']]
# [['が', 'おったが'], ['で', '速力で'], ['と', 'すると']]
# [['が', '書生が']]
# [['か', '動くのか'], ['が', '自分だけが']]
# [['か', '動くのか']]
# [['が', '分らないが'], ['が', '眼が']]
# [['が', '胸が']]
# [['と', '助からないと']]
# [['が', '音が'], ['と', 'どさりと']]
# [['から', '眼から'], ['が', '火が'], ['て', 'して'], ['と', '思っていると']]
# [['は', 'それまでは']]
# [['が', '記憶しているが'], ['は', 'あとは'], ['も', '考え出そうとしても'], ['やら', '事やら']]
# [['が', '気が']]
# [['て', '付いて']]
# [['と', '見ると'], ['は', '書生は']]
# [['が', '兄弟が'], ['も', '一疋も']]
# [['さえ', '母親さえ'], ['を', '姿を']]
# [['は', '所とは']]
# [['を', '眼を']]
# [['て', '這い出して']]
# [['から', '上から'], ['に', '急に'], ['は', '吾輩は'], ['へ', '中へ']]
# [['で', '思いで'], ['を', '笹原を']]
# [['が', '池が'], ['と', '這い出すと'], ['に', '向うに']]
# [['に', '前に']]
# [['て', '坐って']]
# [['と', 'よかろうと']]
# [['て', '考えて'], ['は', '吾輩は']]
# [['も', '分別も']]
# [['て', 'して']]
# [['が', '書生がまた'], ['に', '迎に']]
# [['と', '来てくれるかと']]
# [['に', '試みに']]
# [['て', 'やって']]
# [['が', '見たが'], ['も', '誰も']]
# [['が', '風が'], ['と', 'さらさらと'], ['を', '上を']]
# [['が', '日が'], ['て', '渡って']]
# [['が', '腹が'], ['に', '非常に']]
# [['が', '声が'], ['も', '泣きたくても']]
# [['の', '食物の']]
# [['まで', '所まで']]
# [['と', 'こうと'], ['を', '決心を']]
# [['て', 'して']]
# [['に', '左りに'], ['も', '何でも'], ['を', '池を']]
# [['を', 'そこを']]
# [['て', '我慢して'], ['に', '無理やりに']]
# [['で', '事で'], ['と', '這って行くと'], ['へ', '所へ']]
# [['へ', 'ここへ']]
# [['と', 'なると']]
# [['の', '竹垣の']]
# [['から', '穴から'], ['て', '思って'], ['に', '邸内に']]
# [['が', '竹垣が']]
# [['て', '破れていなかったなら'], ['に', '路傍に'], ['は', '吾輩は']]
# [['は', '蔭とは']]
# [['に', '今日に']]
# [['が', '吾輩が'], ['まで', '至るまで'], ['を', '三毛を']]
# [['に', '通路に'], ['は', '穴は']]
# [['は', '邸へは']]
# [['か', '善いか'], ['ものの', '忍び込んだものの']]
# [['に', 'うちに']]
# [['は', '腹は']]
# [['が', '雨が']]
# [['が', '猶予が'], ['で', '始末で']]
# [['と', '方へと'], ['へ', '方へ']]
# [['から', '今から']]
# [['に', '内に']]
# [['て', '這入って'], ['と', '考えると'], ['は', '時は']]
# [['を', '人間を']]
# [['で', 'ここで'], ['に', '機会に'], ['は', '吾輩は']]
# [['に', '第一に']]
# [['で', '方で'], ['より', '書生より'], ['を', '吾輩を']]
# [['を', '頸筋を']]
# [['で', 'つかんで'], ['は', 'これは'], ['へ', '表へ'], ['や', '見るや']]
# [['と', '駄目だと']]
# [['を', '眼を']]
# [['から', '思ったから'], ['て', 'ねぶって'], ['に', '天に'], ['を', '運を']]
# [['が', '我慢が'], ['は', '寒いのには']]
# [['を', '隙を']]
# [['て', '見て'], ['は', '吾輩は'], ['へ', '台所へ']]
# [['は', '吾輩は'], ['は', '投げ出されては']]
# [['は', '這い上っては']]
# [['でも', '何でも'], ['を', '事を']]
# [['を', '繰り返したのを']]
# [['と', 'おさんと'], ['に', '時に']]
# [['は', '者は']]
# [['を', '返報を'], ['んで', '偸んで']]
# [['から', 'してやってから'], ['が', '痞が']]
# [['が', '吾輩が'], ['に', '最後に']]
# [['と', '何だと']]
# [['が', '主人が'], ['ながら', 'いいながら'], ['に', 'ときに']]
# [['を', '吾輩を']]
# [['へ', '方へ']]
# [['が', '小猫が']]
# [['て', 'ぶら下げて'], ['て', '向けて'], ['も', '出しても']]
# [['へ', '御台所へ']]
# [['て', '上って来て'], ['は', '下女は'], ['も', '出しても']]
# [['と', '困りますと']]
# [['を', '毛を']]
# [['ながら', '撚りながら'], ['を', '顔を']]
# [['て', '眺めて'], ['は', '主人は']]
# [['へ', '内へ']]
# [['が', 'おったが'], ['といった', '置いてやれといったまま'], ['へ', '奥へ']]
# [['を', '口を']]
# [['と', '人と'], ['は', '主人は']]
# [['に', '口惜しそうに'], ['は', '下女は'], ['へ', '台所へ'], ['を', '吾輩を']]
# [['と', '住家と'], ['を', '家を']]
# [['に', '事に'], ['は', '吾輩は']]
# [['と', '吾輩と'], ['に', '滅多に'], ['を', '顔を']]
# [['から', '学校から']]
# [['に', '書斎に']]
# [['と', '帰ると']]
# [['と', '勉強家だと']]
# [['が', 'ものが']]
# [['に', '忍び足に'], ['を', '書斎を']]
# [['て', '覗いて'], ['は', '吾輩は']]
# [['を', '昼寝を']]
# [['が', '事が'], ['が', '見るが'], ['は', '彼は']]
# [['に', '上に'], ['を', '涎を']]
# [['が', '色が'], ['で', '胃弱で'], ['を', '黄色を']]
# [['て', '帯びて'], ['は', '彼は'], ['を', '徴候を']]
# [['に', '癖に'], ['を', '大飯を']]
# [['を', '大飯を']]
# [['で', '後で'], ['を', 'タカジヤスターゼを']]
# [['で', '後で'], ['を', '書物を']]
# [['と', '読むと']]
# [['へ', '上へ'], ['を', '涎を']]
# [['が', 'これが']]
# [['ながら', '猫ながら']]
# [['が', '事が'], ['は', '吾輩は']]
# [['と', '人間と']]
# [['と', '教師と']]
# [['に', 'なるに']]
# [['て', '寝ていて']]
# [['でも', '猫にでも']]
# [['に', '主人に']]
# [['が', '友達が']]
# [['に', '度に'], ['は', '彼は'], ['を', '不平を']]
# [['が', '吾輩が'], ['へ', '家へ']]
# [['へ', 'どこへ']]
# [['も', '行っても']]
# [['て', '跳ね付けられて'], ['に', '相手に']]
# [['に', '今日に']]
# [['さえ', '名前さえ'], ['まで', '至るまで']]
# [['は', '珍重されなかったかは'], ['も', 'つけてくれないのでも']]
# [['を', '吾輩を']]
# [['に', '傍に']]
# [['から', 'ないから'], ['を', '事を']]
# [['が', '朝主人が'], ['を', '新聞を']]
# [['に', '上に'], ['は', 'ときは']]
# [['が', '彼が'], ['を', '昼寝を']]
# [['に', '背中に'], ['は', 'ときは']]
# [['から', 'なかったから'], ['は', 'これは']]
# [['へ', '椽側へ']]
# [['と', '事と'], ['は', '夜は'], ['は', '昼は'], ['は', '朝は']]
# [['に', '夜に']]
# [['へ', '寝床へ']]
# [['て', '入って'], ['で', 'もぐり込んで'], ['に', 'いっしょに']]
# [['で', '三つで'], ['に', '夜に']]
# [['へ', '床へ']]
# [['が', '二人が'], ['て', '入って'], ['と', 'なると'], ['は', '小供というのは'], ['へ', '一間へ']]
# [['でも', 'いつでも'], ['に', '中間に'], ['を', '余地を'], ['を', '己れを']]
# [['か', 'こうにか'], ['て', '見出して'], ['は', '吾輩は']]
# [['が', '一人が'], ['を', '眼を']]
# [['が', '割り込むのであるが'], ['が', '醒ますが'], ['に', '事に']]
# [['が', 'わるい——猫が'], ['が', '方が'], ['が', '質が']]
# [['が', '猫が']]
# [['と', '来たと']]
# [['て', 'いって'], ['で', '声で'], ['でも', '何でも'], ['でも', '夜中でも'], ['は', '小供は——']]
# [['を', '眼を']]
# [['から', '部屋から'], ['て', 'さまして'], ['は', '主人は']]
# [['で', '物指で'], ['は', 'せんだってなどは']]
# [['と', '人間と']]
# [['て', '同居して'], ['を', '彼等を']]
# [['ば', '観察すれば']]
# [['と', 'ものだと'], ['は', '吾輩は'], ['は', '彼等は'], ['ほど', 'ほど']]
# [['が', '吾輩が']]
# [['に', 'ごときに']]
# [['に', '逆さに'], ['を', '人を']]
# [['たり', 'したり'], ['へ', '頭へ'], ['を', '袋を']]
# [['たり', 'かぶせたり']]
# [['たり', '抛り出したり'], ['は', '時は'], ['へ', '中へ']]
# [['で', '方で'], ['でも', '少しでも'], ['を', '手出しを']]
# [['で', '家内総がかりで']]
# [['て', '追い廻して'], ['を', '迫害を']]
# [['で', '畳で'], ['も', 'この間も'], ['を', '爪を']]
# [['が', '細君が'], ['に', '非常に']]
# [['から', 'それから'], ['て', '怒って'], ['に', '容易に'], ['へ', '座敷へ']]
# [['が', '他が'], ['で', '板の間で']]
# [['の', '吾輩の']]
# [['と', 'ないと']]
# [['は', '白君は'], ['を', '子猫を']]
# [['に', '三日目に'], ['へ', '池へ'], ['を', 'そいつを']]
# [['て', '行って'], ['ながら', '四疋ながら']]
# [['が', '書生が'], ['て', '持って'], ['て', '棄てて']]
# [['を', '涙を']]
# [['て', '流して'], ['を', '一部始終を']]
# [['が', '我等猫族が'], ['を', '家族的生活を'], ['を', '愛を']]
# [['と', '人間と']]
# [['て', '戦って'], ['は', 'するには'], ['を', 'これを']]
# [['と', '剿滅せねばならぬと'], ['は', '白君は']]
# [['と', '議論と']]
# [['は', '三毛君などは'], ['を', '事を']]
# [['と', '解していないと']]
# [['て', 'いって'], ['に', '大に']]
# [['に', '先に'], ['も', '臍でも']]
# [['が', 'ものが'], ['を', 'これを']]
# [['が', '権利が']]
# [['と', 'ものと'], ['は', '同族間では']]
# [['が', '相手が'], ['を', '規約を']]
# [['に', '腕力に']]
# [['と', 'ないと']]
# [['が', '我等が'], ['て', '見えて']]
# [['に', 'ために'], ['は', '御馳走は']]
# [['を', '強力を']]
# [['が', '吾人が'], ['で', '頼んで'], ['に', '正当に']]
# [['を', 'ものを']]
# [['て', '奪って'], ['は', '彼等は']]
# [['に', '家に']]
# [['は', '三毛君は'], ['は', '白君は'], ['を', '主人を']]
# [['に', '家に']]
# [['か', 'こうにか'], ['が', '日が']]
# [['も', 'いつまでも']]
# [['を', '時節を'], ['を', '気を']]
# [['で', '我儘で']]
# [['から', '思い出したから'], ['が', '主人が'], ['で', '我儘で']]
# [['を', '話を']]
# [['て', '何といって'], ['に', '人に']]
# [['て', '勝れて']]
# [['が', 'ないが'], ['でも', '何にでも'], ['を', '手を']]
# [['を', '俳句を']]
# [['て', 'やって'], ['へ', 'ほととぎすへ'], ['を', '投書を']]
# [['たり', 'したり'], ['へ', '明星へ'], ['を', '新体詩を']]
# [['たり', '出したり'], ['を', '英文を']]
# [['に', '弓に']]
# [['たり', '凝ったり'], ['を', '謡を']]
# [['たり', '習ったりまた']]
# [['たり', 'かいたり'], ['と', 'よると'], ['は', 'ときは'], ['を', 'ヴァイオリンなどを']]
# [['に', '物に']]
# [['が', '鳴らしたりするが'], ['て', 'なって'], ['は', '事には'], ['も', 'これも'], ['も', 'どれも']]
# [['で', '中で'], ['を', '謡を']]
# [['で', '近所で'], ['を', '渾名を']]
# [['も', 'つけられているにも']]
# [['にて', '宗盛にて'], ['は', 'これは'], ['を', '候を']]
# [['が', 'みんなが'], ['と', 'そら宗盛だと']]
# [['が', '主人が'], ['に', '考に']]
# [['の', '吾輩の']]
# [['から', '住み込んでから'], ['の', '一月ばかり後の']]
# [['を', '包みを']]
# [['か', 'ものか'], ['て', '提げて'], ['に', '月給日に']]
# [['を', '何を']]
# [['と', '買って来たのかと']]
# [['から', '今日から'], ['で', '紙で'], ['を', '俳句を']]
# [['て', 'やめて'], ['と', '思うと'], ['と', '決心と'], ['を', '絵を']]
# [['で', '毎日書斎で'], ['も', '昼寝も']]
# [['で', 'しないで'], ['は', 'ものは'], ['ばかり', '絵ばかり']]
# [['を', 'ものを']]
# [['を', '何を']]
# [['が', '鑑定が'], ['と', '見ると'], ['も', '誰にも'], ['やら', 'ものやら']]
# [['と', '甘くないと']]
# [['で', '友人で'], ['を', '美学とかを']]
# [['が', '人が']]
# [['に', '時に'], ['を', '話を']]
# [['か', 'ものか'], ['を', 'しているのを']]
# [['を', '人のを']]
# [['を', '筆を']]
# [['て', 'とって']]
# [['が', 'ないようだが'], ['と', '見ると'], ['に', '今更のように']]
# [['に', '眼鏡越に'], ['を', '顔を']]
# [['から', '初めから'], ['は', '上手には']]
# [['が', '画が'], ['ばかり', '想像ばかりで']]
# [['が', '大家アンドレア・デル・サルトが']]
# [['が', '事が']]
# [['を', '画を']]
# [['でも', '何でも'], ['を', '物を']]
# [['に', '天に']]
# [['に', '地に']]
# [['に', '飛ぶに']]
# [['に', '走るに']]
# [['に', '池に']]
# [['に', '枯木に']]
# [['も', '君も'], ['を', '画を']]
# [['と', 'かこうと']]
# [['を', '写生を']]
# [['が', 'へえアンドレア・デル・サルトが'], ['を', '事を']]
# [['が', '事が']]
# [['と', 'その通りだと'], ['は', '主人は']]
# [['が', '笑が'], ['は', '裏には']]
# [['に', '椽側に'], ['の', '例のごとく']]
# [['て', '出て'], ['を', '昼寝を']]
# [['から', '書斎から'], ['が', '主人が']]
# [['か', '何か'], ['て', 'していたら'], ['て', '出て来て'], ['で', '後ろで'], ['は', '吾輩は']]
# [['が', '眼が']]
# [['て', '覚めて'], ['を', '何を']]
# [['に', '細目に'], ['を', '眼を']]
# [['て', 'あけて'], ['と', 'しているかと'], ['ばかり', '一分ばかり']]
# [['と', '見ると'], ['は', '彼は'], ['を', 'アンドレア・デル・サルトを']]
# [['を', '有様を']]
# [['て', '見て']]
# [['は', '吾輩は'], ['を', '失笑するのを']]
# [['に', '友に']]
# [['として', '結果として'], ['に', '手初めに'], ['は', '彼は'], ['を', '吾輩を']]
# [['は', '吾輩は']]
# [['が', '欠伸が']]
# [['が', '主人が'], ['に', '熱心に'], ['を', '筆を']]
# [['を', '執っているのを']]
# [['と', '気の毒だと']]
# [['て', '思って'], ['て', '辛棒して']]
# [['を', '輪廓を']]
# [['て', 'かき上げて'], ['は', '彼は'], ['を', 'あたりを']]
# [['は', '吾輩は']]
# [['と', '毛並と']]
# [['と', '造作と']]
# [['に', '猫に']]
# [['て', '思って'], ['は', '勝るとは']]
# [['に', '主人に']]
# [['でも', '吾輩でも'], ['は', '姿とは']]
# [['が', '第一色が']]
# [['の', '猫のごとく'], ['を', '黄を']]
# [['に', '灰色に'], ['は', '吾輩は'], ['を', '皮膚を']]
# [['が', '誰が']]
# [['と', '事実と'], ['は', 'これだけは'], ['も', '見ても']]
# [['を', '彩色を']]
# [['も', '褐色でもない']]
# [['て', 'さればとて'], ['を', 'これらを']]
# [['と', '色であると']]
# [['は', 'これは'], ['を', 'ところを']]
# [['さえ', '所さえ']]
# [['か', '盲猫だか'], ['から', '見えないから']]
# [['か', '猫だか'], ['から', '写生したのだから'], ['が', 'ないが']]
# [['と', 'しようがないと'], ['は', '吾輩は']]
# [['は', '熱心には']]
# [['と', 'におってやりたいと']]
# [['から', 'さっきから'], ['が', '小便が'], ['が', '思ったが']]
# [['は', '筋肉は']]
# [['が', '猶予が'], ['も', '一分も']]
# [['と', '仕儀と']]
# [['て', '失敬して'], ['の', '存分の'], ['へ', '前へ'], ['を', '両足を']]
# [['を', '首を']]
# [['から', 'なったから'], ['て', 'して'], ['て', '押し出して'], ['を', '欠伸を']]
# [['て', 'こうなって']]
# [['に', 'ついでに'], ['へ', '裏へ']]
# [['て', '行って'], ['を', '用を']]
# [['と', '足そうと']]
# [['から', '壊わしたのだから'], ['て', '思って']]
# [['を', '怒りを']]
# [['を', '声を']]
# [['から', '中から'], ['て', 'して'], ['と', '馬鹿野郎と'], ['は', '主人は']]
# [['を', '人を']]
# [['に', 'ほかに'], ['を', '言いようを']]
# [['まで', '今まで']]
# [['も', '気も']]
# [['が', 'ないが'], ['と', '失敬だと']]
# [['が', '吾輩が'], ['へ', '背中へ']]
# [['でも', '顔でも'], ['に', '時に']]
# [['も', '漫罵も']]
# [['て', '甘んじて'], ['も', 'それも']]
# [['の', 'こっちの']]
# [['に', '小便に']]
# [['て', '慢じて'], ['は', 'ものは']]
# [['が', 'ものが']]
# [['て', '出て来て']]
# [['まで', '先どこまで']]
# [['か', '増長するか'], ['は', '窘めてやらなくては']]
# [['くらい', 'くらいなら'], ['も', '我儘も']]
# [['に', '耳に'], ['を', '報道を']]
# [['が', '事が'], ['が', '我慢するが'], ['について', '不徳について'], ['は', '吾輩は'], ['も', 'これよりも']]
# [['が', '茶園が'], ['に', '裏に']]
# [['と', '瀟洒と']]
# [['の', '日の']]
# [['が', '小供が']]
# [['で', '騒いで'], ['の', '昼寝の']]
# [['でも', 'いつでも'], ['へ', 'ここへ']]
# [['て', '出て'], ['を', '気を']]
# [['が', '二時頃であったが'], ['と', '茶園へと'], ['は', '吾輩は'], ['を', '歩を']]
# [['を', '木の根を']]
# [['ながら', '嗅ぎながら'], ['まで', 'そばまで']]
# [['を', '枯菊を']]
# [['が', '猫が'], ['て', '押し倒して'], ['と', 'くると'], ['に', 'その上に'], ['に', '不覚に']]
# [['の', '吾輩の']]
# [['も', '近づくのも']]
# [['を', '鼾を']]
# [['て', 'して'], ['と', '長々と'], ['は', '彼は'], ['を', '体を']]
# [['が', 'ものが'], ['に', '平気に'], ['に', '庭内に'], ['まで', 'かくまで']]
# [['と', 'ものかと'], ['に', '度胸に'], ['に', '窃かに'], ['は', '吾輩は']]
# [['に', 'わずかに'], ['を', '午を']]
# [['に', '上に'], ['を', '光線を']]
# [['て', 'かけて']]
# [['に', '眼に'], ['より', '間より']]
# [['に', '燃え出ずるように'], ['は', '太陽は'], ['も', '炎でも']]
# [['も', '大王とも']]
# [['は', '彼は'], ['を', '体格を']]
# [['は', '倍は']]
# [['に', '心に'], ['を', '前後を']]
# [['て', '忘れて'], ['と', '念と'], ['に', '前に']]
# [['て', '佇立して']]
# [['から', '上から']]
# [['を', '枝を']]
# [['が', '葉が'], ['が', '風が'], ['て', '誘って'], ['と', '眺めていると'], ['に', '茂みに'], ['は', '吾輩は']]
# [['は', '大王は'], ['を', '眼を']]
# [['でも', '今でも']]
# [['の', '人間の']]
# [['は', '眼は'], ['も', 'ものよりも']]
# [['は', '彼は'], ['も', '身動きも']]
# [['から', '奥から']]
# [['に', '上に'], ['を', '光を']]
# [['て', 'あつめて'], ['と', '何だと'], ['は', '御めえは']]
# [['に', '大王に']]
# [['と', '卑しいと']]
# [['に', '底に'], ['も', '犬をも']]
# [['が', 'ぐべき力が']]
# [['が', '思ったが'], ['ので', '籠っているので'], ['は', '吾輩は'], ['を', '恐れを']]
# [['を', '挨拶を']]
# [['と', '険呑だと']]
# [['と', 'ないと'], ['を', '平気を']]
# [['て', '装って'], ['と', '冷然と']]
# [['て', '鼓動して'], ['は', '心臓は']]
# [['に', '大に']]
# [['が', '猫が']]
# [['に', 'どこに']]
# [['に', '家に'], ['は', '吾輩は']]
# [['と', '事だろうと']]
# [['に', 'いやに']]
# [['と', '瘠せてるじゃねえかと'], ['に', '大王だけに'], ['を', '気焔を']]
# [['から', '言葉付から']]
# [['と', '察すると'], ['も', '猫とも']]
# [['て', '切って']]
# [['を', 'ところを']]
# [['と', '見ると'], ['を', '御馳走を']]
# [['に', '豊かに']]
# [['と', '誰だいと'], ['は', '吾輩は']]
# [['で', '近辺で']]
# [['から', 'ないから'], ['も', '誰も']]
# [['に', '的に']]
# [['を', '名を']]
# [['て', '聞いて'], ['は', '吾輩は'], ['を', '感じを']]
# [['と', '起すと同時に'], ['は', '一方では'], ['も', '念も']]
# [['を', '無学であるかを']]
# [['と', '試してみようと']]
# [['を', '問答を']]
# [['て', 'して'], ['て', '思って'], ['は', '吾輩は']]
# [['って', '極って'], ['に', '強いに']]
# [['を', '主人を']]
# [['に', '車屋に']]
# [['が', '御馳走が'], ['と', 'いると']]
# [['と', '食えると']]
# [['へ', '国へ']]
# [['たって', '行ったって'], ['に', '何に'], ['に', '食い物に'], ['は', '不自由は']]
# [['ばかり', '茶畠ばかり'], ['も', '御めえなんかも']]
# [['へ', '後へ']]
# [['て', 'くっ付いて来て'], ['て', '廻っていねえで']]
# [['と', '一と'], ['と', '月と']]
# [['に', 'うちに']]
# [['に', '見違えるように']]
# [['に', '事に']]
# [['に', '大きいのに']]
# [['に', '住んでいるように'], ['は', '家は']]
# [['なんか', 'うちなんか']]
# [['の', '腹の']]
# [['て', 'たって'], ['に', '足しに']]
# [['に', '大に'], ['に', '肝癪に']]
# [['を', '寒竹を']]
# [['を', '耳を']]
# [['と', 'しきりと']]
# [['て', 'ぴく付かせて'], ['で', '様子で'], ['に', 'あららかに'], ['は', '彼は']]
# [['が', '吾輩が'], ['と', '黒と'], ['に', '知己に']]
# [['と', '黒と'], ['は', '吾輩は']]
# [['に', '毎に'], ['は', '彼は'], ['を', '気焔を']]
# [['が', '吾輩が'], ['に', '先に'], ['に', '耳に']]
# [['から', '黒から'], ['も', '不徳事件も']]
# [['で', '中で']]
# [['ながら', '寝転びながら'], ['は', '黒は'], ['を', '雑談を']]
# [['の', 'いつもの']]
# [['に', '新しそうに'], ['を', '自慢話しを']]
# [['に', '吾輩に']]
# [['て', '向って'], ['で', 'あとで'], ['と', 'していると'], ['の', '下のごとく'], ['の', '例のごとく'], ['は', '彼は']]
# [['に', '今までに'], ['を', '鼠を']]
# [['が', '事が'], ['は', '御めえは']]
# [['は', '智識は'], ['も', '黒よりも']]
# [['に', '勇気とに']]
# [['が', '発達しているつもりだが'], ['は', '比較には'], ['は', '至っては']]
# [['と', 'ならないと'], ['は', '覚悟は']]
# [['に', '問に']]
# [['は', '事実は'], ['は', '訳には']]
# [['と', 'とろうと']]
# [['て', '思って']]
# [['から', '行かないから'], ['と', '捕らないと'], ['は', '吾輩は']]
# [['から', '先から']]
# [['と', 'びりびりと'], ['を', '髭を']]
# [['て', '震わせて'], ['に', '非常に'], ['は', '黒は']]
# [['を', '自慢を']]
# [['か', 'どこか'], ['に', '丈に']]
# [['が', 'ところが'], ['は', '黒は']]
# [['て', 'あって'], ['を', '気焔を']]
# [['を', '咽喉を']]
# [['て', '鳴らして'], ['に', '感心したように']]
# [['ば', '謹聴していれば']]
# [['に', '近付に']]
# [['から', 'なってから'], ['を', '呼吸を']]
# [['を', '己れを']]
# [['から', '飲み込んだから'], ['て', '弁護して'], ['も', '場合にも'], ['を', '形勢を']]
# [['に', '事彼に'], ['を', '手柄話を']]
# [['て', 'しゃべらして'], ['を', '御茶を']]
# [['と', '若くはないと'], ['は', '吾輩は'], ['を', '思案を']]
# [['から', '年であるから'], ['は', '君などは']]
# [['て', 'そそのかして'], ['と', 'とったろうと']]
# [['に', '欠所に'], ['は', '彼は']]
# [['が', 'たんとでもねえが'], ['は', '三四十は']]
# [['を', '語を']]
# [['で', '一人で'], ['でも', 'いつでも'], ['は', '二百は']]
# [['が', '引き受けるが'], ['って', 'いたちってえ'], ['て', 'つづけて'], ['に', '手に'], ['は', '奴は'], ['は', '彼は']]
# [['に', 'いたちに']]
# [['て', '向って'], ['に', '目に']]
# [['と', 'へえなるほどと'], ['を', '相槌を']]
# [['を', '眼を']]
# [['て', 'ぱちつかせて'], ['は', '黒は']]
# [['が', '亭主が'], ['を', '袋を']]
# [['て', '持って'], ['へ', '下へ']]
# [['が', '野郎が']]
# [['て', '喰って']]
# [['と', '飛び出したと']]
# [['と', 'ふんと']]
# [['て', '感心して']]
# [['って', 'こん畜生って'], ['で', '気で']]
# [['て', '追っかけて'], ['へ', '中へ']]
# [['と', '追い込んだと']]
# [['ねえ', '思いねえ']]
# [['と', 'やったねと']]
# [['に', '御めえいざってえ段に']]
# [['と', 'なると'], ['を', '奴め最後っ屁を']]
# [['を', 'いたちを']]
# [['に', 'ここに']]
# [['て', '至って'], ['を', '臭気を']]
# [['を', '前足を']]
# [['て', '揚げて'], ['は', '彼は'], ['を', '頭を']]
# [['が', '感じが'], ['も', '吾輩も']]
# [['を', '景気を']]
# [['と', '付けてやろうと']]
# [['に', '君に']]
# [['を', '鼠を']]
# [['が', '捕るのが'], ['で', '名人で'], ['ばかり', '鼠ばかり']]
# [['を', '御機嫌を']]
# [['は', '君は'], ['は', '質問は'], ['も', '不思議にも'], ['を', '結果を']]
# [['として', '喟然として']]
# [['て', '大息して'], ['は', '彼は']]
# [['と', 'えると']]
# [['で', '稼いで'], ['を', '鼠を']]
# [['ほど', '人間ほど']]
# [['って', 'とったって——'], ['に', '世の中に'], ['は', '奴は']]
# [['の', '人の']]
# [['を', '鼠を']]
# [['て', '取り上げやがって'], ['へ', '交番へ']]
# [['て', '持って行きゃ']]
# [['が', '誰が'], ['じゃ', '交番じゃ']]
# [['か', '捕ったか']]
# [['から', '分らねえから'], ['ずつ', '五銭ずつ'], ['に', 'たんびに']]
# [['くらい', '壱円五十銭くらい'], ['で', '御蔭で'], ['なんか', '亭主なんか']]
# [['て', '儲けて']]
# [['に', '癖に'], ['を', '碌なものを']]
# [['も', '事も']]
# [['ぜ', '泥棒だぜさすが'], ['は', '理窟は'], ['も', '黒も']]
# [['と', 'わかると']]
# [['て', '見えて']]
# [['で', '容子で'], ['を', '毛を']]
# [['に', '加減に'], ['を', '場を']]
# [['から', '気味が悪くなったから'], ['て', '胡魔化して'], ['は', '吾輩は'], ['へ', '家へ']]
# [['は', '吾輩は'], ['を', '鼠を']]
# [['から', '時から'], ['と', 'とるまいと']]
# [['に', '子分に']]
# [['って', '猟って'], ['て', 'なって'], ['を', '御馳走を']]
# [['も', '事も']]
# [['を', '御馳走を']]
# [['も', '食うよりも']]
# [['に', '家に']]
# [['と', 'いると'], ['に', '性質に']]
# [['と', 'なると']]
# [['と', '要心しないと'], ['に', '胃弱に']]
# [['と', '教師と']]
# [['に', '近頃に'], ['ば', 'いえば'], ['も', '主人も']]
# [['において', '水彩画において'], ['を', '事を']]
# [['と', 'ものと']]
# [['て', '見えて'], ['に', '日記に'], ['は', '至っては'], ['を', '事を']]
# [['と', 'と']]
# [['で', '会で'], ['に', '人に']]
# [['て', '始めて']]
# [['を', '大分放蕩を']]
# [['と', '人だと']]
# [['が', '云うが']]
# [['は', '人は'], ['を', '風采を']]
# [['に', '女に']]
# [['が', 'ものだからが'], ['を', '放蕩を']]
# [['と', 'したと']]
# [['も', '云うよりも'], ['を', '放蕩を']]
# [['と', 'せられたと']]
# [['を', '元来放蕩家を']]
# [['を', '放蕩を']]
# [['をもって', '放蕩家をもって']]
# [['は', 'これらは']]
# [['に', '無理に'], ['のに', '余儀なくされないのに']]
# [['に', '水彩画に']]
# [['で', 'もので']]
# [['も', 'しかるにも']]
# [['と', '通人だと']]
# [['て', '思って']]
# [['を', '酒を']]
# [['だり', '飲んだり'], ['へ', '待合へ']]
# [['から', '這入るから'], ['と', '通人と']]
# [['が', '論が']]
# [['に', '水彩画家に'], ['も', '吾輩も']]
# [['は', '通人論は']]
# [['を', '妻君を']]
# [['に', '口に']]
# [['の', 'かくのごとく'], ['の', '自知の']]
# [['も', '明あるにも']]
# [['は', '主人は'], ['は', '自惚心は']]
# [['て', '置いて'], ['に', '日記に'], ['を', '事を']]
# [['が', '僕が'], ['を', '水彩画を']]
# [['て', 'かいて'], ['に', '物に'], ['は', '昨夜は']]
# [['と', 'ならんと']]
# [['に', 'そこらに']]
# [['て', '抛って']]
# [['が', '誰かが'], ['に', '額に'], ['を', '置いたのを']]
# [['て', 'して'], ['に', '欄間に']]
# [['て', '思って'], ['を', '夢を']]
# [['に', '額に']]
# [['を', 'ところを']]
# [['と', '見ると'], ['ながら', '我ながら'], ['に', '急に']]
# [['で', '独りで'], ['と', 'ものだと']]
# [['が', '夜が']]
# [['が', '眼が'], ['て', '明けて']]
# [['が', '事が'], ['と', '眺め暮らしていると'], ['と共に', '朝日と共に']]
# [['は', '主人は'], ['まで', '裡まで'], ['を', '未練を']]
# [['と', '背負ってあるいていると']]
# [['も', '謂通人にも']]
# [['が', '主人が'], ['に', '夢に'], ['を', '水彩画を']]
# [['が', '美学者が'], ['で', '久し振りで'], ['を', '主人を']]
# [['に', '座に']]
# [['と', 'つくと'], ['と', 'どうかねと'], ['に', '劈頭第一に'], ['は', '彼は'], ['を', '口を']]
# [['を', '顔を']]
# [['に従って', '忠告に従って'], ['を', '写生を']]
# [['を', '写生を']]
# [['の', '気の'], ['まで', '今まで']]
# [['が', '力めているが'], ['が', '変化などが'], ['て', 'して'], ['と', 'すると'], ['は', '主人は']]
# [['は', '西洋では']]
# [['から', 'しから'], ['を', '写生を']]
# [['に', '今日のように']]
# [['と', 'ものと']]
# [['と', 'アンドレア・デル・サルトだと'], ['は', '事は'], ['も', 'おくびにも']]
# [['で', '出さないでまた'], ['に', 'アンドレア・デル・サルトに']]
# [['と', '出鱈目だよと'], ['ながら', '笑いながら'], ['は', '美学者は'], ['を', '頭を']]
# [['と', '何がと'], ['に', '事に'], ['は', '主人は']]
# [['の', '君の']]
# [['の', '僕の']]
# [['が', '君が'], ['に', '真面目に']]
# [['は', '信じようとは']]
# [['で', '椽側で'], ['を', '対話を']]
# [['が', '事が'], ['は', '日記には']]
# [['て', '聞いて'], ['と', '記さるるであろうかと'], ['は', '吾輩は']]
# [['を', '事を']]
# [['て', '吹き散らして'], ['を', '人を']]
# [['の', '唯一の'], ['を', '担ぐのを']]
# [['が', 'アンドレア・デル・サルト事件が'], ['に', '情線に'], ['を', '響を']]
# [['を', '伝えたかを']]
# [['に', '得意に'], ['ものの', '顧慮せざるもののごとく']]
# [['て', 'なって'], ['は', '彼は'], ['を', '事を']]
# [['を', '冗談を']]
# [['が', '人が'], ['と', '言うと']]
# [['に', '大に'], ['ので', '受けるので'], ['を', '滑稽的美感を']]
# [['が', 'ニコラス・ニックルベーが'], ['に', 'ギボンに'], ['に', '学生に']]
# [['て', '忠告して'], ['の', '一世の']]
# [['で', '仏語で'], ['を', '仏国革命史を']]
# [['を', '書くのを']]
# [['て', 'やめにして'], ['で', '英文で']]
# [['と', '出版させたと']]
# [['に', '真面目に'], ['の', '僕の']]
# [['が', '学生が'], ['で', '演説会で'], ['で', '男で'], ['に', '馬鹿に'], ['を', '通りを']]
# [['に', '熱心に'], ['を', 'それを']]
# [['が', '約百名ばかりであったが'], ['て', '傾聴して']]
# [['が', '話が']]
# [['の', '文学者の']]
# [['の', '歴史小説セオファーノの']]
# [['が', '話しが'], ['で', '席で']]
# [['が', '女主人公が']]
# [['は', 'ところは'], ['を', '鬼気人を']]
# [['と', '襲うようだと']]
# [['に', '向うに']]
# [['て', '坐っている']]
# [['と', '知らんと']]
# [['が', '先生が'], ['と', '名文だと']]
# [['も', '男も'], ['を', '小説を']]
# [['は', '僕は'], ['を', '事を']]
# [['を', '眼を']]
# [['て', '丸くして'], ['は', '主人は']]
# [['を', '出鱈目を']]
# [['が', '相手が'], ['て', 'いって']]
# [['で', '読んでいたら']]
# [['を', '人を']]
# [['が', '皮が']]
# [['は', '時は']]
# [['と', '困るじゃないかと']]
# [['は', '美学者は'], ['も', '少しも']]
# [['と', '本と']]
# [['とか', '間違えたとか']]
# [['と', '云うばかりさと']]
# [['て', '云って']]
# [['は', '眼鏡は'], ['は', '美学者は']]
# [['が', '性質が'], ['に', '黒に']]
# [['が', 'ところが'], ['が', '掛けているが']]
# [['に', '輪に'], ['を', '日の出を']]
# [['と', 'ないと']]
# [['は', '主人は'], ['を', '顔を']]
# [['を', '画を']]
# [['に', '門下生に'], ['を', 'しみを']]
# [['と', '写せと']]
# [['が', '事が'], ['が', '冗談だが'], ['で', '目付で'], ['は', 'レオナルド・ダ・ヴィンチは'], ['は', '美学者は'], ['よ', 'ものだよ']]
# [['に', 'なるほど雪隠などに']]
# [['の', '雨の']]
# [['て', '這入って'], ['を', '壁を']]
# [['が', '模様画が'], ['と', '眺めていると'], ['に', '自然に']]
# [['て', '注意して']]
# [['が', 'ものが'], ['て', '写生して']]
# [['から', '出来るから']]
# [['か', '語じゃないか'], ['でも', 'ダ・ヴィンチでも']]
# [['と', '相違ないなと'], ['は', '主人は'], ['を', '半分降参を']]
# [['で', '雪隠で'], ['は', '写生は'], ['は', '彼は']]
# [['に', '跛に'], ['は', '黒は']]
# [['が', '色が']]
# [['て', '褪めて'], ['は', '毛は']]
# [['と', '美しいと']]
# [['が', '眼脂が'], ['は', '眼には']]
# [['を', '注意を']]
# [['と', '消沈と'], ['の', '体格の']]
# [['が', '吾輩が'], ['で', '茶園で'], ['に', '彼に']]
# [['と', 'どうだと']]
# [['て', '云って']]
# [['と', '懲だと']]
# [['に', '間に'], ['を', '紅を']]
# [['の', '夢のごとく']]
# [['て', '散って'], ['に', 'つくばいに'], ['を', '花弁を']]
# [['は', '紅葉は'], ['も', '山茶花も']]
# [['が', '日脚が'], ['に', '椽側に']]
# [['の', '木枯の']]
# [['から', '稀になってから'], ['も', '時間も']]
# [['が', '気が'], ['て', '傾いて'], ['は', '日は']]
# [['は', '主人は'], ['へ', '毎日学校へ']]
# [['と', '帰ると'], ['へ', '書斎へ']]
# [['が', '人が']]
# [['と', '厭だと']]
# [['に', '滅多に'], ['も', '水彩画も']]
# [['と', 'ないと']]
# [['て', 'いって'], ['も', 'タカジヤスターゼも']]
# [['に', '感心に']]
# [['で', '休まないで'], ['は', '小供は'], ['へ', '幼稚園へ']]
# [['と', '帰ると'], ['を', '唱歌を']]
# [['て', '歌って'], ['を', '毬を']]
# [['て', 'ついて'], ['で', '尻尾で'], ['を', '吾輩を']]
# [['は', '吾輩は'], ['も', '御馳走も']]
# [['から', '食わないから']]
# [['も', '跛にも']]
# [['が', '肥りもしないが'], ['に', 'ならずに'], ['を', 'その日を']]
# [['は', '鼠は']]
# [['は', '名前は']]
# [['を', '欲を']]
# [['から', 'ないから'], ['が', 'つけてくれないが'], ['で', '家で'], ['で', '猫で'], ['も', 'いっても']]
# [['は', '吾輩は']]
# [['が', '鼻が'], ['ながら', '猫ながら']]
# [['が', '絵端書が'], ['へ', '許へ']]
# [['で', '深緑りで'], ['を', '上部を'], ['を', '下部を']]
# [['が', '動物が'], ['て', '塗って'], ['に', '真中に']]
# [['が', '年始状であるが'], ['で', 'パステルで'], ['を', 'ところを']]
# [['から', '横から']]
# [['から', '竪から'], ['たり', '見たり'], ['で', '書斎で'], ['を', '絵を']]
# [['と', '色だなと']]
# [['に', 'やめに']]
# [['と', 'するかと']]
# [['から', '横から']]
# [['から', 'ものだから'], ['から', '竪から'], ['たり', '見たり'], ['と', '思うと']]
# [['を', 'からだを']]
# [['を', '手を']]
# [['が', '年寄が'], ['たり', '拗じ向けたり'], ['て', '延ばして'], ['を', '三世相を']]
# [['へ', '方へ']]
# [['て', 'むいて'], ['まで', '先まで']]
# [['たり', '見るようにしたり'], ['て', '持って来たりして']]
# [['が', '膝が']]
# [['が', '動揺が'], ['で', '事で']]
# [['と', '劇しくなくなったと']]
# [['で', '声で'], ['を', '何を']]
# [['と', 'かいたのだろうと']]
# [['は', '主人は'], ['は', '色には']]
# [['が', '正体が']]
# [['から', 'さっきから'], ['を', '苦心を']]
# [['が', '感服したが'], ['と', 'ものと'], ['ので', '分らぬので']]
# [['と', '絵端書かと']]
# [['に', '上品に'], ['を', '眼を']]
# [['て', '払って']]
# [['に', '主人のように'], ['を', 'アンドレア・デル・サルトを']]
# [['に', '画家だけに'], ['も', '色彩も']]
# [['が', 'ものでもあるまいが'], ['て', '整って']]
# [['が', '誰が']]
# [['の', '眼識の']]
# [['が', '事が'], ['と', '判然と']]
# [['に', 'わかるように'], ['に', '立派に']]
# [['を', '事を']]
# [['くらい', 'くらい'], ['に', '分らずに'], ['まで', 'かくまで']]
# [['と', '苦心するかと']]
# [['が', '人間が'], ['と', '思うと']]
# [['が', '絵が'], ['と', '吾輩であると']]
# [['を', '事を']]
# [['と', '吾輩であると']]
# [['は', '事は']]
# [['は', '事だけは'], ['も', '分らないにしても']]
# [['を', '言語を']]
# [['に', 'くらいに'], ['に', '恵に']]
# [['から', 'おらん動物であるから'], ['ながら', '残念ながら'], ['に', 'そのままに']]
# [['に', '読者に']]
# [['と', '何ぞと']]
# [['に', '事もなげに'], ['を', '口調を']]
# [['て', 'もって'], ['と', '猫と'], ['を', '吾輩を']]
# [['が', '癖が']]
# [['から', '糟から'], ['が', '馬が']]
# [['から', '糞から'], ['が', '猫が']]
# [['て', '出来て']]
# [['に', '無智に']]
# [['を', '顔を']]
# [['から', 'はたから']]
# [['て', '見て']]
# [['だって', '猫だって'], ['は', '粗末簡便には']]
# [['に', '社会に']]
# [['て', '這入って']]
# [['が', '応用が'], ['が', '特色などはないようであるが'], ['で', 'もので'], ['と', '見ると'], ['は', '語は'], ['も', 'ここにも']]
# [['も', '足並でも']]
# [['から', '張り具合から'], ['に', '垂れ加減に']]
# [['を', '数を']]
# [['て', '悉くして'], ['と', '千差万別と']]
# [['も', '云っても']]
# [['が', '区別が'], ['に', 'そのように']]
# [['とか', '向上とか']]
# [['て', 'いって'], ['ばかり', '空ばかり']]
# [['を', '末を']]
# [['すら', '事すら'], ['は', '性質は']]
# [['は', '求むとは']]
# [['が', '語だそうだが'], ['で', '猫で'], ['は', '猫でなくては']]
# [['が', '人間が']]
# [['を', '実際を']]
# [['が', '彼等が']]
# [['は', '主人のごときは'], ['を', '相互を']]
# [['と', '解すると']]
# [['すら', 'ことすら']]
# [['に', '書斎に'], ['の', '牡蠣のごとく']]
# [['に', '外界に']]
# [['て', '向って'], ['を', '口を']]
# [['は', '自分だけは']]
# [['を', '面構を']]
# [['が', '肖像が'], ['に', '前に'], ['は', '証拠には']]
# [['のに', 'あるのに'], ['も', '少しも']]
# [['と', '画だろうなどと'], ['の', '気の']]
# [['を', 'ことを']]
# [['から', '第二年目だから'], ['て', 'いって'], ['は', '今年は']]
# [['も', 'すましているのでも']]
# [['で', '上で'], ['を', '眼を']]
# [['が', '吾輩が'], ['ながら', 'ねむりながら']]
# [['が', '下女が'], ['と', '考えていると'], ['を', '絵端書を']]
# [['が', '猫が'], ['で', '活版で']]
# [['を', 'ペンを']]
# [['たり', '握ったり'], ['を', '書物を']]
# [['たり', '開いたり'], ['て', '行列して'], ['と', '見ると'], ['を', '勉強を']]
# [['を', '席を']]
# [['じゃ', '猫じゃ'], ['て', '離れて'], ['で', '角で'], ['は', '一疋は'], ['を', '猫じゃを']]
# [['で', '墨で'], ['と', '黒と']]
# [['に', '側に'], ['を', '書を']]
# [['さえ', '俳句さえ'], ['て', 'かいて'], ['に', 'その上に'], ['や', '読むや']]
# [['は', 'これは'], ['より', '旧門下生より']]
# [['が', '誰が'], ['ので', '来たので']]
# [['って', '見たって']]
# [['が', '意味が'], ['て', '一見して']]
# [['のに', 'わかるはずであるのに'], ['は', '主人は']]
# [['と', '悟らないと']]
# [['て', '見えて'], ['に', '不思議そうに'], ['を', '首を']]
# [['て', '捻って'], ['と', '年かなと'], ['は', '今年は'], ['を', '独言を']]
# [['が', '吾輩が'], ['ほど', 'これほど']]
# [['が', '気が'], ['を', '有名になったのを']]
# [['に', '着かずに']]
# [['と', 'いると']]
# [['が', '下女が'], ['へ', 'ところへ'], ['を', '端書を']]
# [['と', '恭賀新年と']]
# [['て', 'かいて'], ['と', '願上候と'], ['に', '傍らに'], ['も', '猫へも']]
# [['に', 'さまに']]
# [['て', '書いて'], ['も', '主人でも']]
# [['ば', 'あれば']]
# [['と', 'ものと']]
# [['が', '気が'], ['て', '見えて']]
# [['と', 'フンと']]
# [['ながら', '言いながら'], ['に', '付いたように'], ['を', '顔を']]
# [['は', '今までとは']]
# [['て', '違って'], ['を', '意を']]
# [['が', '眼付が'], ['に', '含んでいるように']]
# [['から', '世間から'], ['まで', '今まで'], ['を', '存在を']]
# [['が', '主人が'], ['に', '急に'], ['を', '新面目を']]
# [['と', '御蔭だと']]
# [['と', '至当だろうと'], ['も', 'こしたのも']]
# [['から', 'おりから'], ['が', '格子が'], ['と', 'チリリリリンと']]
# [['が', '下女が'], ['に', '取次に']]
# [['が', '梅公が']]
# [['に', '事に'], ['は', 'ほかは'], ['は', '吾輩は']]
# [['に', '膝に']]
# [['から', '極めているのだから'], ['て', '坐って'], ['の', 'もとのごとく']]
# [['でも', '高利貸にでも']]
# [['に', '飛び込まれたように'], ['を', '顔付を']]
# [['て', 'して'], ['は', '主人は'], ['を', '方を']]
# [['でも', '何でも'], ['を', '客を']]
# [['て', '受けて'], ['を', '相手を']]
# [['くらい', 'くらい'], ['も', '人間も']]
# [['も', '外出でも']]
# [['を', '根性を']]
# [['が', '下女が']]
# [['が', '寒月さんが'], ['て', '来て'], ['と', 'すると'], ['に', 'おいでに']]
# [['と', 'なりましたと']]
# [['は', '今では'], ['を', '学校を']]
# [['て', '卒業して'], ['でも', '何でも'], ['より', '主人より']]
# [['が', '旧門下生であったそうだが'], ['という', '立派になっているという']]
# [['か', '訳か'], ['に', '遊びに'], ['へ', '所へ']]
# [['って', '恋って'], ['と', '来ると'], ['を', '自分を']]
# [['が', '女が']]
# [['ばかり', '文句ばかり']]
# [['は', '並べては']]
# [['を', '人間を']]
# [['を', '話しを']]
# [['に', 'しに']]
# [['から', '来るのから']]
# [['が', '合点が'], ['て', 'して'], ['て', '求めて']]
# [['が', '牡蠣的主人が'], ['を', '談話を']]
# [['て', '聞いて'], ['を', '相槌を']]
# [['を', '御無沙汰を']]
# [['から', '暮から'], ['に', '大に']]
# [['と', '出よう出ようと']]
# [['から', 'ものですから'], ['が', '足が'], ['へ', '方角へ'], ['も', '思っても']]
# [['を', '紐を']]
# [['と', '向かないのでと'], ['ながら', 'ひねくりながら']]
# [['を', '事を']]
# [['が', '足が'], ['へ', '方角へ']]
# [['を', '顔を']]
# [['て', 'して'], ['と', 'かねと'], ['は', '主人は'], ['を', '袖口を']]
# [['かい', '短かい'], ['から', '下から'], ['が', 'べら者が'], ['ずつ', '五分くらいずつ'], ['は', '羽織は'], ['へ', '左右へ'], ['ん', 'べん']]
# [['が', '寒月君が'], ['と', '方角でと']]
# [['が', '前歯が'], ['と', '見ると'], ['は', '今日は']]
# [['を', '君歯を']]
# [['と', 'どうかしたかねと'], ['は', '主人は'], ['を', '問題を']]
# [['で', '所で'], ['を', '椎茸を']]
# [['ね', '食いましてね'], ['を', '何を']]
# [['を', '椎茸を']]
# [['で', '前歯で'], ['を', '傘を']]
# [['が', '歯が'], ['と', 'ぼろりと'], ['と', '噛み切ろうとしたら']]
# [['が', '前歯が'], ['で', '椎茸で']]
# [['は', '俳句には']]
# [['が', 'なるかも知れないが'], ['は', '恋には']]
# [['で', '平手で'], ['と', 'ならんようだなと'], ['を', '頭を']]
# [['か', '例のですか']]
# [['だって', '黒にだって']]
# [['も', '負けそうも']]
# [['と', '大きくなったのさと'], ['に', '自慢そうに'], ['を', '頭を']]
# [['と', 'ちょいと'], ['も', '一昨夜も'], ['を', '合奏会を']]
# [['と', 'やりましてねと'], ['は', '寒月君は'], ['へ', 'もとへ'], ['を', '話しを']]
# [['で', 'どこで'], ['でも', 'どこでも'], ['に', '御聞きに']]
# [['に', '三挺くらいに'], ['も', 'ヴァイオリンも']]
# [['でも', '下手でも'], ['と', 'なると']]
# [['が', '私が'], ['で', '女で'], ['は', '二人は'], ['へ', '中へ']]
# [['も', '自分でも']]
# [['が', 'まじりましたが'], ['と', '弾けたと']]
# [['と', '何者かねと'], ['に', '羨ましそうに'], ['は', '主人は']]
# [['は', '顔付は']]
# [['を', '小説を']]
# [['に', '中に']]
# [['が', '一人物が']]
# [['が', 'それが'], ['て', '出て来て'], ['は', '主人は'], ['は', '婦人には'], ['は', '方ではない'], ['ものの', 'しているものの']]
# [['を', '勘定を']]
# [['て', 'して']]
# [['と', '見ると'], ['を', '往来を']]
# [['は', '七割弱には']]
# [['が', '事が'], ['に', '諷刺的に']]
# [['を', '書いてあったのを']]
# [['と', '真理だと']]
# [['が', '男が'], ['を', '牡蠣的生涯を']]
# [['と', '送っているかと']]
# [['は', '云うのは'], ['は', '吾輩猫などには']]
# [['は', '人は'], ['も', 'ためだとも']]
# [['も', 'せいだとも']]
# [['し', '云うし'], ['し', '云うしまた'], ['て', 'なくて'], ['は', '人は'], ['は', '人は'], ['も', '性質だからだとも']]
# [['に', 'どっちに']]
# [['って', 'したって'], ['に', '歴史に']]
# [['から', '人物でもないのだから']]
# [['に', '気に'], ['を', '女連れを']]
# [['で', '箸で'], ['に', '面白そうに'], ['を', '蒲鉾を']]
# [['で', '半分前歯で'], ['で', '挟んで'], ['は', '寒月君は']]
# [['は', '吾輩はまた'], ['は', '欠けは']]
# [['と', 'せぬかと']]
# [['も', '二人とも']]
# [['と', '方じゃありませんと']]
# [['を', '返事を']]
# [['と', 'ナールと'], ['は', '主人は']]
# [['を', 'ほどを']]
# [['が', '引張ったが'], ['て', '略して']]
# [['と', '時分だと']]
# [['で', '散歩で'], ['に', 'ごいっしょに']]
# [['か', 'もしましょうか'], ['が', '旅順が'], ['な', '天気ですな']]
# [['が', '促が'], ['と', '景気ですよと']]
# [['か', 'ものか'], ['て', 'して'], ['は', '寒月君は']]
# [['より', '陥落より'], ['を', '身元を']]
# [['と', '聞きたいと']]
# [['で', '顔で']]
# [['が', '考え込んでいたが'], ['を', '決心を']]
# [['と', 'ものと']]
# [['じゃ', 'それじゃ']]
# [['と', '出ると']]
# [['と', 'しようと']]
# [['て', '思い切って'], ['て', '見えて'], ['は', '主人は']]
# [['とかいう', '紀念とかいう']]
# [['に', '紋付羽織に'], ['を', '綿入を']]
# [['が', '所々が']]
# [['て', '薄くなって'], ['に', '日に']]
# [['て', '透かして']]
# [['から', '裏から'], ['を', 'つぎを']]
# [['が', '目が'], ['と', '見ると']]
# [['を', '懐手を']]
# [['て', 'して'], ['は', 'ときは']]
# [['に', 'ほかに']]
# [['か', 'ないからか'], ['から', '面倒だから']]
# [['か', '着換えないのか'], ['は', '吾輩には']]
# [['は', 'これだけは'], ['も', 'ためとも']]
# [['が', '両人が']]
# [['て', '出て']]
# [['の', '寒月君の']]
# [['て', '失敬して'], ['で', 'あとで'], ['は', '吾輩は'], ['を', '残りを']]
# [['か', '猫か'], ['は', '資格は']]
# [['と', 'あると']]
# [['くらい', '一切くらい']]
# [['から', '人から'], ['って', '頂戴したって']]
# [['を', '人目を']]
# [['で', '忍んで'], ['を', '間食を']]
# [['に', '吾等猫族に'], ['も', '何も']]
# [['に', '留守中に'], ['を', '餅菓子などを']]
# [['は', '失敬しては']]
# [['は', '御三などは'], ['は', '頂戴しては']]
# [['を', '仕付を']]
# [['から', '細君から'], ['と', '受けつつあると']]
# [['が', '傾向が'], ['すら', '小児ですら']]
# [['から', '早くから'], ['が', '小供が'], ['に', '馬鹿に'], ['を', '眼を']]
# [['の', '主人夫婦の']]
# [['に', '間に']]
# [['が', 'ことであったが'], ['て', '対い合うて'], ['て', '覚まして'], ['に', '食卓に']]
# [['の', '毎朝主人の']]
# [['を', '砂糖を']]
# [['て', 'つけて'], ['に', '幾分に']]
# [['が', '砂糖壺が'], ['に', '上に']]
# [['が', '例であるが'], ['さえ', '匙さえ'], ['て', '置かれて'], ['は', '日は']]
# [['に', 'いつものように'], ['を', '砂糖を']]
# [['から', '中から'], ['が', '方が'], ['を', '砂糖を']]
# [['て', 'すくい出して'], ['ので', 'ないので'], ['へ', '上へ']]
# [['が', '小さいのが'], ['の', '姉の']]
# [['で', '同方法で'], ['に', '上に'], ['を', '砂糖を']]
# [['は', '少らく両人は']]
# [['を', '匙を']]
# [['が', '大きいのが'], ['が', '睨み合っていたが'], ['て', 'とって'], ['に', '上に'], ['を', '一杯を']]
# [['を', '匙を']]
# [['て', 'とって'], ['に', '同一に'], ['も', '小さいのも'], ['を', '分量を']]
# [['が', '姉がまた']]
# [['も', '妹も']]
# [['に', '負けずに'], ['を', '一杯を']]
# [['へ', '壺へ'], ['を', '手を']]
# [['が', '妹が'], ['が', '姉が'], ['を', '匙を']]
# [['と', '一杯と'], ['に', '間に']]
# [['が', '砂糖が'], ['は', '皿には']]
# [['も', '砂糖も']]
# [['て', '余って']]
# [['が', '主人が']]
# [['を', '眼を']]
# [['ながら', '擦りながら'], ['を', '寝室を']]
# [['て', '出て来て']]
# [['て', '堆くなって'], ['て', '重なって'], ['は', 'ついには'], ['は', '中には'], ['へ', '中へ'], ['を', '砂糖を']]
# [['を', 'ところを']]
# [['から', '利己主義から']]
# [['は', '念は'], ['より', '猫より']]
# [['が', '優っているかも知れぬが'], ['と', '見ると'], ['は', '智慧は'], ['より', '猫より']]
# [['に', 'うちに']]
# [['と', '甞めてしまえばいいにと']]
# [['の', '吾輩の']]
# [['の', '例のごとく'], ['は', '事などは']]
# [['から', '上から'], ['ながら', '気の毒ながら']]
# [['から', '通じないのだから'], ['が', '思ったが'], ['て', '黙って']]
# [['と', '寒月君と']]
# [['を', 'どこを']]
# [['に', '食卓に']]
# [['から', '上から']]
# [['て', 'だまって'], ['と', '拝見していると'], ['は', '主人は'], ['を', '雑煮を']]
# [['は', '代えては']]
# [['は', '代えては']]
# [['か', '六切か'], ['でも', '何でも']]
# [['て', '七切食って'], ['へ', '中へ'], ['を', '一切れを']]
# [['が', '小さいが'], ['て', '残して'], ['と', 'よそうと'], ['を', '箸を']]
# [['が', '他人が'], ['を', '我儘を']]
# [['と', 'すると']]
# [['を', '威光を']]
# [['に', '中に']]
# [['を', '死骸を']]
# [['が', '承知しないのであるが'], ['て', '廻わして'], ['て', '見て'], ['は', '彼は']]
# [['から', '奥から'], ['が', '妻君が'], ['を', 'タカジヤスターゼを']]
# [['て', '出して'], ['に', '上に']]
# [['は', 'それは']]
# [['から', '利かないから'], ['と', '置くと'], ['は', '主人は']]
# [['と', '飲まんと']]
# [['が', '大変功能が'], ['は', 'ものには']]
# [['から', 'あるそうですから']]
# [['と', '召し上ったらいいでしょうと']]
# [['と', '駄目だよと'], ['に', '頑固に']]
# [['は', 'あなたは']]
# [['と', '厭きっぽいと'], ['に', '独言のように']]
# [['が', '薬が']]
# [['に', '大変に']]
# [['は', 'せんだってじゅうは']]
# [['と', '利くと']]
# [['だって', 'それだって'], ['て', 'おっしゃって']]
# [['は', 'こないだうちは']]
# [['か', '上ったじゃありませんか'], ['は', '頃は'], ['よ', '利いたのだよ']]
# [['と', '利かないのだよと'], ['を', '返事を']]
# [['だり', '飲んだり']]
# [['の', '功能の']]
# [['も', '薬でも']]
# [['ちゃ', '止めたりしちゃ'], ['は', '気遣いは']]
# [['ちゃあ', 'よくなくっちゃあ'], ['て', '違って'], ['は', '胃弱なんぞは']]
# [['を', 'お盆を']]
# [['て', '持って']]
# [['と', '直らないわねえと'], ['を', '御三を']]
# [['て', '召し上って'], ['に', 'ご覧に']]
# [['か', '薬か'], ['と', 'ならないと']]
# [['と', 'わかりますまいと'], ['は', '御三は'], ['を', '肩を']]
# [['でも', '何でも']]
# [['から', '飲まんのだから']]
# [['が', '何が'], ['に', '女なんかに']]
# [['か', 'ものか']]
# [['が', '細君が'], ['と', '女ですわと'], ['へ', '前へ'], ['を', 'タカジヤスターゼを']]
# [['て', '突き付けて'], ['を', '詰腹を']]
# [['も', '何にも']]
# [['て', '立って'], ['は', '主人は'], ['へ', '書斎へ']]
# [['を', '顔を']]
# [['て', '見合せて'], ['と', 'にやにやと'], ['は', '御三は']]
# [['に', 'ときに']]
# [['て', '付いて行って'], ['へ', '上へ']]
# [['と', '乗ると'], ['に', '目に']]
# [['から', '庭から']]
# [['て', '廻って'], ['へ', '椽側へ']]
# [['から', '隙から']]
# [['から', '逢わされるから'], ['て', '上って'], ['て', '覗いて']]
# [['とか', 'エピクテタスとか']]
# [['を', '本を']]
# [['て', '披いて'], ['て', '見て'], ['と', '見ると'], ['は', '主人は']]
# [['が', 'それが']]
# [['が', 'ところが']]
# [['と', 'すると'], ['を', '本を']]
# [['に', '叩き付けるように'], ['へ', '上へ']]
# [['と', '事だろうと']]
# [['ながら', '思いながら']]
# [['を', '日記帳を']]
# [['て', '出して'], ['と', '注意していると'], ['は', '今度は'], ['を', '事を']]
# [['が', '芸者が'], ['で', '前で'], ['を', '春着を']]
# [['て', 'きて'], ['を', '羽根を']]
# [['に', '猫に']]
# [['に', '例に'], ['も', '何も'], ['を', '吾輩を']]
# [['へ', '喜多床へ']]
# [['さえ', '顔さえ'], ['て', '行って']]
# [['と', '人間と']]
# [['だって', '吾輩だって'], ['は', 'ところは']]
# [['は', '人間は']]
# [['から', '自惚れているから']]
# [['を', '角を']]
# [['が', '一人芸者が'], ['と', '曲ると']]
# [['と', 'すらりと']]
# [['に', '素直に'], ['も', '衣服も']]
# [['て', '着こなされて'], ['で', '女で'], ['に', '上品に'], ['は', 'これは']]
# [['を', '歯を']]
# [['て', '出して']]
# [['が', '忙が']]
# [['と', 'もんだからと'], ['ながら', '笑いながら']]
# [['て', '皺枯れて'], ['の', '旅鴉のごとく'], ['は', '声は']]
# [['に', '大に'], ['も', '風采も']]
# [['に', '下落したように'], ['ので', 'おったので']]
# [['ものの', '源ちゃんなるものの']]
# [['を', '人なるかを']]
# [['て', '振り向いて']]
# [['も', '見るも']]
# [['から', '感ぜられたから'], ['て', '面倒になって'], ['へ', '御成道へ']]
# [['て', 'そわそわしているごとく'], ['は', '寒月は']]
# [['ほど', '心理ほど']]
# [['は', '心は']]
# [['か', '怒っているのだか']]
# [['に', '遺書に'], ['を', '慰安を']]
# [['か', '求めつつあるのか']]
# [['を', '世の中を']]
# [['か', '交りたいのだか'], ['に', '事に'], ['を', '肝癪を']]
# [['か', '起しているのか'], ['と', '超然と'], ['に', '物外に']]
# [['か', 'しているのだか'], ['が', '見当が']]
# [['は', '猫などは'], ['へ', 'そこへ']]
# [['ば', '食いたければ']]
# [['ば', '寝たければ']]
# [['に', '一生懸命に'], ['は', 'ときは']]
# [['に', '絶体絶命に'], ['は', 'ときは']]
# [['は', 'ものは']]
# [['に', '主人のように'], ['の', '裏表の']]
# [['でも', '日記でも']]
# [['て', '書いて'], ['に', '世間に']]
# [['に', '暗室内に'], ['を', '面目を']]
# [['が', '必要が'], ['は', '人間は']]
# [['に', '我等猫属に']]
# [['を', '手数を']]
# [['て', 'して'], ['を', '真面目を']]
# [['から', '日記であるから'], ['が', 'あるかも知れないが'], ['は', '保存するには']]
# [['と', '及ばぬと']]
# [['を', '日記を']]
# [['が', 'ひまが']]
# [['に', '椽側に']]
# [['で', '某亭で'], ['を', '晩餐を']]
# [['で', '久し振りで'], ['を', '正宗を']]
# [['と', '一番だと']]
# [['は', 'タカジヤスターゼは']]
# [['が', '誰が'], ['と', '何と']]
# [['って', 'どうしたって']]
# [['は', 'ものは']]
# [['を', 'タカジヤスターゼを']]
# [['で', '独りで'], ['を', '喧嘩を']]
# [['が', '肝癪が'], ['へ', 'ここへ'], ['を', '尾を']]
# [['に', '云う辺に'], ['は', '本色は']]
# [['は', 'せんだっては'], ['を', '朝飯を']]
# [['が', '胃が'], ['と', '廃すると']]
# [['と', 'なると']]
# [['を', '朝飯を']]
# [['から', '云うたから'], ['て', 'やめて']]
# [['が', '腹が']]
# [['を', '是非香の物を']]
# [['と', '断てと'], ['は', 'は']]
# [['に', '説に']]
# [['と', 'よると'], ['に', '漬物に'], ['は', '源因は']]
# [['さえ', '漬物さえ']]
# [['ば', '断てば'], ['を', '源を']]
# [['から', '涸らす訳だから'], ['は', '本復は']]
# [['に', '香の物に'], ['ばかり', '一週間ばかり'], ['を', '箸を']]
# [['も', '験も']]
# [['から', '見えなかったから'], ['が', '触れなかったが'], ['は', '近頃は']]
# [['に', 'に']]
# [['と', '聞くと'], ['に', '按腹揉療治に'], ['は', 'それは']]
# [['は', '普通のでは']]
# [['という', '皆川流という'], ['な', '古流な']]
# [['で', '揉み方で']]
# [['は', '胃病は'], ['ば', 'やらせれば']]
# [['も', '安井息軒も'], ['を', '按摩術を']]
# [['は', '時々は'], ['も', '豪傑でも'], ['を', '治療を']]
# [['と', 'うけたと']]
# [['まで', '上根岸まで']]
# [['て', '出掛けて']]
# [['から', '云うから'], ['て', '揉まして']]
# [['を', '骨を']]
# [['とか', '癒らぬとか'], ['ば', '揉まなければ'], ['を', '位置を']]
# [['が', '根治が']]
# [['とか', 'しにくいとか'], ['ば', '顛倒しなければ']]
# [['て', 'いって'], ['は', 'それは'], ['は', 'それは'], ['を', '揉み方を']]
# [['に', '昏睡病に']]
# [['が', '心持ちが'], ['が', '身体が'], ['て', '綿のようになって']]
# [['で', '一度で']]
# [['て', '閉口して'], ['に', 'やめに'], ['ので', 'したので']]
# [['は', '君は'], ['を', '是非固形体を']]
# [['と', '食うなと']]
# [['ばかり', '一日牛乳ばかり']]
# [['で', '飲んで']]
# [['て', '暮して']]
# [['ど', '中でど']]
# [['ど', 'ぼりど']]
# [['が', '音が'], ['と', 'ぼりと']]
# [['て', 'して'], ['も', '大水でも']]
# [['に', '出たように']]
# [['が', '見たが'], ['て', '思われて'], ['は', '時は']]
# [['で', '横膈膜で']]
# [['て', '呼吸して'], ['を', '内臓を']]
# [['が', '働きが'], ['ば', '運動させれば']]
# [['に', '試しに']]
# [['と', '御覧と']]
# [['も', 'これも']]
# [['が', 'やったが']]
# [['に', '一心不乱に']]
# [['に', '思い出したように'], ['は', 'かかりは']]
# [['ものの', 'ものの']]
# [['と', '立つと']]
# [['と', '忘れまいと']]
# [['が', '横膈膜が'], ['に', '気に']]
# [['て', 'なって'], ['を', '本を']]
# [['と', 'すると'], ['も', '事も'], ['を', '文章を']]
# [['も', '事も']]
# [['が', '迷亭が'], ['を', '体を']]
# [['の', '産気の']]
# [['し', '男じゃあるまいし']]
# [['と', '止すがいいと']]
# [['から', '冷かしたから'], ['て', '見て'], ['は', '頃は']]
# [['を', '蕎麦を']]
# [['と', 'よかろうと'], ['は', '先生は']]
# [['から', '云うから'], ['を', 'かけともりを']]
# [['が', '腹が']]
# [['を', '胃弱を']]
# [['に', 'ために']]
# [['を', '方法を']]
# [['て', '講じて']]
# [['と', '寒月と']]
# [['が', '利目が'], ['は', '正宗は']]
# [['ずつ', '二三杯ずつ']]
# [['に', '事に'], ['は', 'これからは']]
# [['も', 'これも']]
# [['は', '心は']]
# [['を', '何を']]
# [['の', '永持の'], ['も', 'やっても']]
# [['で', '上で'], ['を', '胃病を']]
# [['に', '大に'], ['を', '痩我慢を']]
# [['が', '学者が'], ['で', '友人で']]
# [['から', '見地から'], ['て', '尋ねて来て'], ['に', '結果に'], ['は', '病気は']]
# [['と', 'ほかならないと']]
# [['を', '議論を']]
# [['と', 'ものと']]
# [['を', 'これを']]
# [['が', '自分が'], ['で', '胃病で']]
# [['を', '弁解を']]
# [['て', 'して'], ['を', '面目を']]
# [['と', '保とうと']]
# [['と', '者と']]
# [['から', '胃弱だから'], ['と', '名誉であると']]
# [['から', '際だから'], ['を', '挨拶を']]
# [['が', '病人が'], ['だって', '胃弱だって'], ['は', 'カーライルには']]
# [['と', 'なれないさと'], ['は', '友人は']]
# [['と', '黙然と'], ['ので', '極め付けたので'], ['は', '主人は']]
# [['に', '虚栄心に'], ['の', 'かくのごとく']]
# [['と', 'いいと']]
# [['から', '今夜から'], ['て', '見えて'], ['を', '晩酌を']]
# [['て', '考えて']]
# [['を', '雑煮を']]
# [['を', '正宗を']]
# [['と', '見ると'], ['も', '食ったのも']]
# [['が', '雑煮が']]
# [['て', '食って'], ['も', '吾輩も']]
# [['は', '吾輩は']]
# [['が', '猫ではあるが'], ['は', 'ものは']]
# [['に', '黒のように'], ['まで', '肴屋まで'], ['を', '遠征を']]
# [['の', '小供の']]
# [['も', '麺麭も']]
# [['し', '食うし'], ['も', 'も']]
# [['ばかり', '二切ばかり'], ['を', '沢庵を']]
# [['が', 'まずいが'], ['が', '事が']]
# [['て', '食って']]
# [['は', 'ものは']]
# [['と', '嫌だと']]
# [['で', '我儘で'], ['に', '家に']]
# [['に', '口に']]
# [['の', '主人の']]
# [['に', '話しに']]
# [['が', '小説家が'], ['と', 'よると'], ['に', '仏蘭西に']]
# [['に', '小説家だけに'], ['を', '贅沢を']]
# [['が', 'バルザックが'], ['の', '自分の']]
# [['を', '名を']]
# [['と', 'つけようと']]
# [['て', 'つけて'], ['て', '思って']]
# [['が', '見たが'], ['も', 'どうしても']]
# [['が', '友人が'], ['に', '遊びに'], ['へ', 'ところへ']]
# [['に', 'いっしょに'], ['に', '散歩に'], ['ので', '来たので']]
# [['も', '何も'], ['より', '固より']]
# [['に', '知らずに'], ['は', '友人は']]
# [['て', '兼ねて'], ['の', '自分の']]
# [['へ', '往来へ']]
# [['と', '出ると'], ['も', '何も']]
# [['で', 'しないで'], ['ばかり', '看板ばかり']]
# [['から', '考えだから'], ['が', '連れ出されたのであるが'], ['て', '見て']]
# [['を', '友人を']]
# [['て', '連れて']]
# [['が', '訳が']]
# [['に', 'わからずに'], ['は', '友人は']]
# [['から', '朝から'], ['は', '彼等は'], ['まで', '晩まで'], ['を', '巴理を']]
# [['が', '看板が'], ['に', '帰りがけに'], ['に', '目に'], ['は', 'バルザックは']]
# [['が', '名が'], ['と', '見ると'], ['に', '看板に']]
# [['って', '拍って'], ['に', 'これに'], ['は', 'バルザックは'], ['を', '手を']]
# [['を', '頭文字を']]
# [['が', '名が']]
# [['は', 'でなくては']]
# [['で', '自分で']]
# [['は', '名は']]
# [['が', 'ところが']]
# [['で', '事で']]
# [['が', '名が']]
# [['と', '出来たと'], ['は', '迷惑は']]
# [['て', '忘れて']]
# [['と', '嬉しがったと']]
# [['を', '名前を']]
# [['に', 'つけるに'], ['を', '一日巴理を']]
# [['の', '手数の']]
# [['くらい', 'くらい'], ['も', '贅沢も']]
# [['に', '吾輩のように'], ['を', '牡蠣的主人を']]
# [['が', 'ものだが'], ['は', '気は'], ['は', '身の上では']]
# [['でも', '何でも']]
# [['に', '気に']]
# [['の', '境遇の']]
# [['が', '今雑煮が']]
# [['でも', '何でも']]
# [['に', '時に'], ['は', '結果ではない']]
# [['の', '主人の']]
# [['が', '雑煮が'], ['に', '台所に']]
# [['から', '考から'], ['は', '残っていは']]
# [['と', 'すまいかと']]
# [['へ', '台所へ']]
# [['て', '廻って']]
# [['が', '餅が'], ['で', '色で'], ['に', '底に']]
# [['に', '口に'], ['まで', '今まで'], ['も', '一辺も']]
# [['と', '見ると'], ['も', 'うまそうにも']]
# [['が', '気味が'], ['し', 'あるしまた'], ['は', '少しは']]
# [['で', '前足で'], ['に', '上に']]
# [['を', '菜っ葉を']]
# [['を', '爪を']]
# [['が', '上皮が']]
# [['て', '引き掛って'], ['と', '見ると']]
# [['で', '嗅いで']]
# [['へ', '御櫃へ'], ['を', '飯を']]
# [['が', '香が'], ['と', '見ると']]
# [['な', '食おうかな']]
# [['と', 'やめようかなと'], ['を', 'あたりを']]
# [['か', '不幸か'], ['も', '誰も']]
# [['も', '春も'], ['を', '顔を']]
# [['て', 'して'], ['は', '御三は'], ['を', '羽根を']]
# [['で', '奥座敷で'], ['は', '小供は'], ['を', '兎さんを']]
# [['と', '食うと']]
# [['を', '機を']]
# [['を', '味を']]
# [['と', 'はずすと'], ['に', '知らずに']]
# [['ながら', '猫ながら'], ['に', '刹那に'], ['は', '吾輩は'], ['を', '真理を']]
# [['を', '動物を']]
# [['て', 'して'], ['て', '敢て'], ['は', '機会は'], ['も', '事をも']]
# [['を', '実を']]
# [['と', '云うと'], ['は', '吾輩は'], ['を', '雑煮を']]
# [['を', '様子を']]
# [['ば', '熟視すれば']]
# [['ほど', 'ほど']]
# [['て', '気味が悪くなって']]
# [['が', '食うのが']]
# [['でも', '御三でも'], ['を', '勝手口を']]
# [['が', '足音が'], ['へ', 'こちらへ']]
# [['を', '近付くのを']]
# [['を', '椀を']]
# [['に', '念頭に'], ['は', '事は'], ['は', '吾輩は'], ['まで', '来年まで']]
# [['も', '誰も']]
# [['も', 'いくら躇していても'], ['も', '誰も']]
# [['か', '食わぬか']]
# [['と', '食わぬかと']]
# [['が', '心持が']]
# [['を', '中を']]
# [['か', '誰か'], ['ながら', '覗き込みながら']]
# [['と', '来てくれればいいと'], ['は', '吾輩は']]
# [['も', '誰も']]
# [['は', '吾輩は'], ['を', '雑煮を']]
# [['へ', '底へ'], ['を', '重量を']]
# [['て', '落すようにして'], ['ばかり', '一寸ばかり'], ['を', '角を']]
# [['を', '力を']]
# [['くらい', 'くらい'], ['て', '込めて']]
# [['から', '食い付いたのだから']]
# [['と', 'よかろうと']]
# [['て', '思って'], ['を', '歯を']]
# [['が', '噛み切れる訳だが'], ['と', '引こうとすると']]
# [['が', '動きが'], ['と', '噛み直そうとすると']]
# [['と', '魔物だなと']]
# [['も', '沼へでも']]
# [['が', '人が'], ['を', '足を']]
# [['と', '抜こうと'], ['に', 'たびに']]
# [['ば', '噛めば']]
# [['が', '口が'], ['に', '沈むように'], ['ほど', 'ほど']]
# [['が', '歯が']]
# [['は', '歯答えは']]
# [['が', '歯答えが']]
# [['で', 'あるだけで'], ['を', '始末を']]
# [['が', 'あるが'], ['が', '事が']]
# [['が', '美学者迷亭先生が'], ['を', '主人を']]
# [['が', '事が'], ['て', '評して'], ['は', '君は']]
# [['を', '事を']]
# [['に', '同じように'], ['も', '餅も']]
# [['も', '噛んでも']]
# [['で', '三で'], ['を', '十を']]
# [['の', '尽未来際方の']]
# [['と', 'あるまいと']]
# [['に', '真理に'], ['は', '吾輩は']]
# [['に', '直覚的に'], ['は', '動物は'], ['を', '適不適を']]
# [['は', '真理は'], ['まで', '二つまで']]
# [['が', '餅が']]
# [['が', '発明したが'], ['ので', 'くっ付いているので'], ['を', '愉快を']]
# [['が', '歯が'], ['に', '肉に']]
# [['て', '食い切って']]
# [['が', '御三が'], ['と', '逃げないと']]
# [['も', '唱歌も']]
# [['へ', '台所へ']]
# [['を', '極尻尾を']]
# [['て', 'ぐるぐる振って']]
# [['を', '耳を']]
# [['たり', '立てたり']]
# [['て', '考えて']]
# [['の', '立て損の']]
# [['と', '寝かし損であると']]
# [['から', '気が付いたから']]
# [['を', '助けを']]
# [['て', '借りて'], ['を', '餅を']]
# [['に', '払い落すに'], ['は', '事これは']]
# [['と', '限ると']]
# [['を', '方を']]
# [['て', 'あげて'], ['を', '周囲を']]
# [['くらい', 'くらいで']]
# [['を', '方を']]
# [['て', '伸して'], ['として', '中心として'], ['に', '急劇に'], ['を', '円を']]
# [['て', '劃して'], ['は', '今度は']]
# [['で', '呪いで'], ['は', '魔は']]
# [['と', '肝心だと']]
# [['て', '思って'], ['に', '交るに']]
# [['が', '動かしたが'], ['に', '中に'], ['は', '歯は']]
# [['と', '面倒だと'], ['に', '一度に'], ['を', '両足を']]
# [['で', '二本で']]
# [['が', '事が'], ['に', '事に'], ['は', '時だけは']]
# [['が', '感じが']]
# [['にゃ', '日にゃあ']]
# [['が', '魔が'], ['でも', '何でも']]
# [['まで', '落ちるまで']]
# [['か', 'ものか'], ['が', 'あるまいが'], ['が', '猫であろうが'], ['で', '意気込みで'], ['に', '無茶苦茶に']]
# [['を', '中心を']]
# [['て', '失って'], ['ので', '猛烈なので']]
# [['で', '後足で'], ['に', 'たびに'], ['を', '調子を']]
# [['に', '一つ所に']]
# [['から', 'とらなくてはならぬから'], ['も', '訳にも']]
# [['と', 'こちらと']]
# [['で', '飛んで'], ['ので', '行かんので']]
# [['ながら', '我ながら'], ['に', '器用に']]
# [['と', 'ものだと']]
# [['が', '真理が'], ['に', '驀地に']]
# [['に', '危きに']]
# [['ば', '臨めば'], ['を', 'ものを']]
# [['が', '吾輩が'], ['と', '魔と'], ['に', '天祐という幸に'], ['を', '天祐を']]
# [['が', '足音が']]
# [['が', '人が'], ['て', 'して'], ['より', '奥より']]
# [['で', 'ここで'], ['に', '人に']]
# [['と', '大変だと']]
# [['と', '躍起と']]
# [['て', 'なって'], ['て', '思って'], ['を', '台所を']]
# [['は', '足音は']]
# [['が', '天祐が'], ['が', '残念だが']]
# [['に', '小供に']]
# [['が', 'あら猫が'], ['を', '御雑煮を']]
# [['て', '食べて'], ['を', '踊を']]
# [['と', '踊っていると'], ['を', '声を']]
# [['に', '第一に'], ['を', '声を']]
# [['も', '羽子板も']]
# [['から', '勝手から'], ['て', '打ち遣って'], ['と', 'あらまあと']]
# [['で', '紋付で'], ['と', '猫ねえと'], ['は', '細君は']]
# [['から', '書斎から'], ['さえ', '主人さえ']]
# [['て', '出て来て'], ['と', '馬鹿野郎と']]
# [['と', '面白いと']]
# [['に', '申し合せたように']]
# [['は', '腹は']]
# [['に', '訳に']]
# [['は', '苦しくはある'], ['は', '踊は']]
# [['が', '笑いが']]
# [['に', 'やみそうになったら'], ['に', '五つに']]
# [['が', '女の子が'], ['と', '随分ねと']]
# [['に', '既倒に'], ['を', '狂瀾を']]
# [['ので', 'いったので']]
# [['も', '実行も']]
# [['へ', 'どっかへ'], ['も', '天祐も']]
# [['て', '消え失せて'], ['に', '通り四つ這に']]
# [['て', 'なって'], ['を', '眼を']]
# [['を', '醜態を']]
# [['に', '演ずるまでに']]
# [['に', '見殺しに']]
# [['と', '気の毒と']]
# [['を', '餅を']]
# [['が', '主人が'], ['て', '見えて'], ['と', 'とってやれと'], ['に', '御三に']]
# [['で', '眼付で'], ['は', '御三は'], ['を', '細君を']]
# [['は', '細君は'], ['は', '踊は']]
# [['まで', '殺してまで']]
# [['が', '見たいが'], ['ので', 'ないので']]
# [['て', '取って']]
# [['と', 'やらんと']]
# [['で', '死んでしまう']]
# [['と', 'とってやれと'], ['は', '主人は'], ['を', '下女を']]
# [['を', '御馳走を']]
# [['から', '夢から'], ['て', '食べかけて']]
# [['を', '顔を']]
# [['て', 'して'], ['を', '餅を']]
# [['で', 'つかんで'], ['に', '時のように'], ['は', '御三は']]
# [['が', '前歯が']]
# [['が', '寒月君じゃないが'], ['と', '折れるかと']]
# [['へ', '中へ']]
# [['って', '痛くないのって'], ['を', '歯を']]
# [['は', '安楽は'], ['を', '困苦を']]
# [['と', '通過せざるべからずと']]
# [['が', '吾輩が'], ['を', '真理を']]
# [['て', '経験して'], ['と', 'けろけろと'], ['を', 'あたりを']]
# [['へ', '奥座敷へ']]
# [['て', '這入ってしまって'], ['は', '家人は'], ['は', '時には']]
# [['を', '失敗を']]
# [['に', '内に']]
# [['て', 'いて'], ['に', '御三なんぞに'], ['は', '時には'], ['を', '顔を']]
# [['を', '事気を']]
# [['て', '易えて'], ['も', '三毛子でも']]
# [['から', '台所から'], ['と', '訪問しようと'], ['へ', '裏へ']]
# [['が', '相違ないが'], ['は', '吾輩は'], ['は', '情けは']]
# [['で', 'うちで'], ['を', '顔を']]
# [['を', '険突を']]
# [['が', '気分が'], ['て', '食って']]
# [['を', '許を']]
# [['たり', '見たり'], ['て', '訪問して'], ['は', '時は'], ['を', '話を']]
# [['が', '心が']]
# [['て', '晴々して'], ['も', '苦労も']]
# [['て', '忘れて'], ['に', '心持に']]
# [['から', '隙から']]
# [['と', 'いるかなと']]
# [['て', '思って']]
# [['を', '新しいのを']]
# [['から', '正月だから'], ['て', 'して'], ['と', '見渡すと'], ['に', '椽側に']]
# [['が', '丸さ加減が']]
# [['に', '言うに']]
# [['を', '美を']]
# [['の', '尻尾の']]
# [['の', '足の']]
# [['に', '物憂げに'], ['を', '耳を']]
# [['が', '形容が'], ['も', '景色なども']]
# [['の', '日の']]
# [['に', '暖かそうに']]
# [['を', '態度を']]
# [['を', '天鵞毛を']]
# [['の', '春の']]
# [['を', '光りを']]
# [['て', '反射して'], ['と', 'むらむらと'], ['に', 'なきに']]
# [['から', 'ものだから'], ['に', '微動するごとくに'], ['は', '満身の毛は'], ['は', '身体は'], ['も', '有するにも']]
# [['として', '恍惚として'], ['は', '吾輩は']]
# [['に', '我に']]
# [['で', '声で'], ['と', '三毛子さんと']]
# [['が', '眺めていたが'], ['で', '前足で'], ['と', '帰ると同時に'], ['ながら', 'いいながら']]
# [['と', 'あら先生と'], ['は', '三毛子は'], ['を', '椽を']]
# [['に', '首輪に']]
# [['に', '正月に']]
# [['まで', '鈴まで']]
# [['と', '音だと']]
# [['に', '傍に']]
# [['て', '来て'], ['と', 'おめでとうと'], ['に', '間に'], ['へ', '左りへ'], ['を', '尾を']]
# [['で', '吾等猫属間で'], ['を', '挨拶を']]
# [['の', '棒のごとく'], ['は', 'ときには'], ['を', '尾を']]
# [['て', '立てて'], ['と', 'ぐるりと'], ['へ', '左りへ'], ['を', 'それを']]
# [['で', '町内で'], ['と', '先生と'], ['を', '吾輩を']]
# [['に', '家に']]
# [['は', '三毛子だけは']]
# [['から', 'ものだから'], ['が', 'ないのであるが'], ['て', '尊敬して'], ['と', '先生先生と']]
# [['と', '先生と'], ['も', '吾輩も']]
# [['て', '云われて'], ['も', '心持ちも']]
# [['から', 'しないから'], ['と', 'はいはいと'], ['を', '返事を']]
# [['が', '御化粧が'], ['に', '立派に']]
# [['に', '暮御師匠さんに']]
# [['ね', '出来ましたね'], ['の', '買って頂いたの']]
# [['て', 'ゃらちゃら鳴らして']]
# [['な', '音ですな'], ['は', '吾輩などは']]
# [['よ', 'ないですよ']]
# [['と', 'ぶら下げるのよと']]
# [['わ', '嬉しいわ']]
# [['に', 'ゃらちゃらちゃらちゃら続け様に']]
# [['は', '御師匠さんは'], ['を', 'あなたを']]
# [['と', '可愛がっていると']]
# [['と', '見えますねと'], ['に', '吾身に']]
# [['て', '引きくらべて'], ['を', '意を']]
# [['と', '小供のようよと'], ['は', '三毛子は']]
# [['だって', '猫だって']]
# [['は', '笑わないとは']]
# [['に', 'ほかに'], ['より', '自分より']]
# [['に', '無いように'], ['は', '人間は']]
# [['が', '吾輩が']]
# [['に', '三角に'], ['を', '孔を']]
# [['て', 'して'], ['を', '咽喉仏を']]
# [['て', '震動させて'], ['は', '笑うのは']]
# [['から', '笑うのだから'], ['は', '人間には']]
# [['は', 'それは'], ['も', '吾輩も'], ['よ', '御師匠さんよ']]
# [['を', '君を']]
# [['が', '御師匠さんが'], ['で', '内で'], ['を', '二絃琴を']]
# [['と', '宜い声でしょうと'], ['は', '三毛子は']]
# [['が', 'いようだが'], ['は', '吾輩には']]
# [['か', 'ものですか']]
# [['で', '六十二で']]
# [['と', '丈夫と']]
# [['から', 'くらいだから'], ['ば', '云わねば']]
# [['と', 'はあと'], ['は', '吾輩は'], ['を', '返事を']]
# [['が', '間が']]
# [['が', '抜けたようだが'], ['も', '名答も']]
# [['でも', 'いつでも']]
# [['でも', '何でも'], ['に', '御嫁に']]
# [['だって', '娘なんだって']]
# [['に', '御嫁に']]
# [['に', '御嫁に'], ['よ', 'そうよ']]
# [['に', '御嫁に']]
# [['よ', '行ったですよ']]
# [['に', '御嫁に']]
# [['て', '混雑して'], ['を', '要領を']]
# [['に', '何に']]
# [['か', 'なるんですか'], ['も', 'あなたも']]
# [['に', '御嫁に']]
# [['だって', '娘なんだって']]
# [['から', '先っきっから']]
# [['か', '言ってるんじゃありませんか'], ['は', 'それは']]
# [['が', 'それが'], ['さえ', '分りさえ']]
# [['から', 'ないから'], ['を', '降参を']]
# [['と', '時と']]
# [['を', '虚言を']]
# [['が', '事が'], ['と', 'すると'], ['は', '吾は']]
# [['が', '音が'], ['で', '中で']]
# [['で', '声で'], ['と', 'やむと'], ['と', '御飯だよと']]
# [['が', 'あら御師匠さんが']]
# [['から', '呼んでいらっしゃるから']]
# [['と', 'わるいと']]
# [['じゃ', 'それじゃまた'], ['に', '遊びに']]
# [['と', 'いらっしゃいと'], ['を', '鈴を']]
# [['まで', '庭先まで']]
# [['て', 'かけて'], ['て', '鳴らして']]
# [['に', '急に']]
# [['と', 'どうかしやしなくってと'], ['に', '心配そうに']]
# [['を', '雑煮を']]
# [['て', '食って'], ['を', '踊りを']]
# [['も', '踊ったとも']]
# [['も', '事も']]
# [['を', '考え事を']]
# [['から', '云われないから'], ['が', 'ありませんが'], ['が', '頭痛が']]
# [['と', 'あなたと']]
# [['でも', '話しでも']]
# [['と', '直るだろうと']]
# [['て', '思って']]
# [['に', '御大事に']]
# [['に', '気に'], ['は', '少しは']]
# [['で', 'これで'], ['と', 'さっぱりと'], ['も', '元気も']]
# [['に', '心持に']]
# [['に', '帰りに'], ['を', '茶園を']]
# [['と', '通り抜けようと']]
# [['の', '霜柱の']]
# [['を', '融けかかったのを']]
# [['から', '崩れから'], ['ながら', '踏みつけながら'], ['を', '顔を']]
# [['が', '黒が'], ['に', '上に'], ['に', '山に'], ['を', '背を']]
# ...
# [['に', '高潮度に']]
# [['に', '普通以上に'], ['を', '程度を']]
# [['が', '個性が'], ['て', 'もって'], ['において', '今代において']]
# [['が', '青年男女が'], ['に', '劣情に'], ['も', 'あるにも']]
# [['を', '全力を']]
# [['に', '蛮風に'], ['は', '吾人は']]
# [['で', '平手で'], ['で', '調子で'], ['と', 'ぴたりと'], ['と', '反対ですと'], ['は', '東風君は'], ['を', '膝頭を']]
# [['と', '尊いと']]
# [['と', 'ないと']]
# [['を', '吾を']]
# [['を', '吾を']]
# [['に', '完全にし'], ['を', '吾を']]
# [['を', '情操を']]
# [['に', '優美にし'], ['を', '品性を']]
# [['に', '高潔にし'], ['を', '同情を']]
# [['の', 'いつの']]
# [['に', '世いずくに']]
# [['も', '生れても'], ['を', 'ものを']]
# [['が', 'ことが'], ['は', '吾人は']]
# [['が', '者が'], ['に', '現実世界に']]
# [['と', '夫婦と']]
# [['と', 'あらわれると'], ['に', '関係に'], ['は', '愛は']]
# [['に', '形式に'], ['は', '美は']]
# [['に', '表面に']]
# [['は', '芸術は']]
# [['と', 'なかろうと']]
# [['が', '今哲学者が']]
# [['が', '結構だが'], ['と', 'ないと']]
# [['だって', '芸術だって'], ['に', '運命に']]
# [['と', '自由と']]
# [['と', '自由と']]
# [['と', '人と']]
# [['なんか', '芸術なんか']]
# [['が', '芸術が']]
# [['が', '一致が'], ['に', '間に'], ['は', '繁昌するのは']]
# [['を', '詩を']]
# [['と', '面白いと']]
# [['に', 'ほかに'], ['は', '読み手は'], ['より', '君より']]
# [['を', '鴛鴦歌を']]
# [['って', '作ったって']]
# [['に', '今日に'], ['に', '幸いに']]
# [['が', '天下が']]
# [['から', '生れたから'], ['て', '挙って']]
# [['でも', 'それほどでも']]
# [['の', '人文の']]
# [['が', '一大哲学者が']]
# [['て', '出て'], ['を', '非結婚論を']]
# [['は', 'よみ手は'], ['は', '時分には'], ['ば', 'それほどでなければ'], ['も', '誰も']]
# [['を', '個性を']]
# [['の', '人の']]
# [['が', '傾向が'], ['でも', '今でも'], ['は', '英国などでは']]
# [['で', '小説家中で'], ['に', '作品に']]
# [['を', 'メレジスを']]
# [['を', 'ジェームスを']]
# [['の', '個性の']]
# [['が', '傾向が']]
# [['が', '婚姻が'], ['て', '発達して']]
# [['も', '芸術も']]
# [['の', '君の']]
# [['に', '僕に'], ['は', 'ものは']]
# [['の', '僕の']]
# [['に', '君に']]
# [['けれども', 'そうですけれども'], ['に', '直覚的に'], ['は', '私は']]
# [['が', '君が'], ['に', '直覚的に']]
# [['に', '曲覚的に'], ['は', '僕は'], ['ば', '思われなければ']]
# [['が', '独仙君が'], ['と', '曲覚的かも知れないがと'], ['は', '今度は'], ['を', '口を']]
# [['に', '人間に'], ['を', '自由を']]
# [['ば', '許せば']]
# [['が', 'ニーチェが'], ['なんか', '超人なんか']]
# [['の', '窮屈の']]
# [['が', 'やりどころが']]
# [['て', 'なくなって'], ['に', '仕方なしに'], ['に', '哲学に'], ['も', '担ぎ出すのも']]
# [['が', 'あれが'], ['と', '見ると'], ['に', '理想のように']]
# [['の', '個性の']]
# [['に', '十九世紀に']]
# [['で', 'すくんで'], ['に', '滅多に'], ['は', '人には'], ['も', '寝返りも']]
# [['に', 'やけに']]
# [['から', '打てないから'], ['て', 'なって'], ['を', '乱暴を']]
# [['を', 'あれを']]
# [['と', '壮快と']]
# [['と', '読むと'], ['より', '云うより']]
# [['が', '人が']]
# [['として', '天下翕然として'], ['に', '旗下に'], ['は', 'そのはずさ昔は'], ['ば', 'あれば'], ['も', 'それも']]
# [['が', '愉快が'], ['に', '事実に']]
# [['も', '何も']]
# [['で', '力で'], ['に', '上に'], ['を', 'これを']]
# [['も', 'チェヴィ・チェーズでも'], ['を', '性格を']]
# [['が', '感じが'], ['も', '写しても']]
# [['に', '愉快に']]
# [['が', '事実が']]
# [['て', 'あって'], ['に', '紙に'], ['を', '事実を']]
# [['は', 'そうは'], ['は', '時代は']]
# [['なんか', '英雄なんか'], ['も', '一人も']]
# [['って', '出たって'], ['と', '英雄と'], ['も', '誰も']]
# [['から', '一人だったから'], ['も', '孔子も'], ['を', '幅を']]
# [['が', '利かしたのだが'], ['が', '孔子が'], ['は', '今は'], ['も', '幾人も']]
# [['が', '天下が'], ['と', 'よると']]
# [['と', '孔子だよと']]
# [['が', '圧が'], ['は', 'おれは'], ['も', '威張っても']]
# [['から', '不平だから'], ['で', '上だけで'], ['を', '超人などを']]
# [['を', '自由を']]
# [['て', '欲して'], ['は', '吾人は'], ['を', '自由を']]
# [['を', '自由を']]
# [['を', '不自由を']]
# [['て', '感じて']]
# [['に', 'これに']]
# [['じゃ', '東洋じゃ'], ['て', '反して']]
# [['から', '昔しから'], ['を', '修行を']]
# [['を', '神経衰弱を']]
# [['が', '始末が'], ['て', '起して']]
# [['と', '民蕩々たりと']]
# [['を', '価値を']]
# [['て', '始めて']]
# [['て', '無為にして']]
# [['と', '化すと']]
# [['に', '馬鹿に']]
# [['を', '事を']]
# [['に', 'アルコール中毒に']]
# [['を', '酒を']]
# [['て', '罹って'], ['と', 'よかったと']]
# [['も', '伺っても']]
# [['が', '寒月君が'], ['と', 'ものでしょうと']]
# [['を', '妻君を']]
# [['が', '迷亭君が'], ['と', '持ち立てだからさと']]
# [['が', '主人が'], ['を', '事を']]
# [['を', '妻を']]
# [['と', 'ものだなどと']]
# [['と', '思うと']]
# [['に', '間違に']]
# [['を', '物を']]
# [['から', 'ためだから'], ['で', '読んで']]
# [['から', '最前書斎から']]
# [['と', '聴くがいいと'], ['を', '本を']]
# [['から', '時代から'], ['が', '本だが'], ['は', '事は']]
# [['て', '取り上げて'], ['と', '分ってると']]
# [['と', '本ですかと']]
# [['と', 'タマス・ナッシと']]
# [['を', '悪口を']]
# [['が', 'ものが']]
# [['が', '悪口が']]
# [['は', '内には'], ['も', '妻も']]
# [['から', '這入る訳だから'], ['が', 'あるが']]
# [['に', '事に']]
# [['が', '賢哲が'], ['を', '女性観を']]
# [['と', '紹介すべしと']]
# [['まで', '僕まで']]
# [['を', '嫁を']]
# [['は', 'アリストートル曰く女は'], ['ば', '碌でなしなれば'], ['より', '嫁より'], ['を', '嫁を']]
# [['で', '碌で']]
# [['で', '碌で']]
# [['で', '碌で']]
# [['を', 'さああとを']]
# [['は', '名前は']]
# [['が', 'ダイオジニスが'], ['は', '次には']]
# [['を', '妻を']]
# [['において', '時において']]
# [['で', '中で']]
# [['に', 'ピサゴラス曰く天下に']]
# [['を', '濶な事を']]
# [['に', '僕に']]
# [['と', '云わせると'], ['に', '天下に']]
# [['に', '火に']]
# [['て', '入って']]
# [['に', '水に']]
# [['て', '入って']]
# [['で', '溺れずだけで']]
# [['に', '女に']]
# [['て', '逢って']]
# [['が', '迷亭先生が'], ['と', 'とろけずだろうと'], ['に', '援兵に']]
# [['は', '主人は'], ['を', 'あとを']]
# [['を', '婦女子を']]
# [['を', '敵を']]
# [['と', '苦しめんと'], ['も', 'デモスセニス曰く人も']]
# [['に', '敵に'], ['を', '女を']]
# [['は', '得たるは'], ['ば', 'せば'], ['より', '与うるより']]
# [['に', '風波に'], ['を', '彼を']]
# [['を', 'むるを']]
# [['と', '婦女と']]
# [['て', '無学をもって'], ['と', '二大厄と'], ['は', 'セネカは']]
# [['に', '船舶に'], ['において', '点において'], ['は', 'マーカス・オーレリアスは'], ['は', '女子は']]
# [['と', '似たりと']]
# [['が', '女子が'], ['を', '綺羅を']]
# [['を', '性癖を']]
# [['て', 'もって'], ['を', '醜を']]
# [['に', '陋策に']]
# [['に', '友某に'], ['を', 'つて書を']]
# [['か', 'ヴァレリアスか'], ['て', 'おくって']]
# [['の', '女子の']]
# [['で', '忍んで']]
# [['て', '告げて'], ['に', '曰く天下に'], ['も', '何事も']]
# [['を', '皇天憐を']]
# [['を', '君を']]
# [['て', 'して'], ['に', '術中に']]
# [['に', '敵に']]
# [['に', '苦しみに']]
# [['に', '害に'], ['や', 'あらずや']]
# [['に', '誘惑に'], ['や', 'あらずや']]
# [['に', '蜜に']]
# [['に', '毒に']]
# [['を', '彼等を']]
# [['と', '呵責と'], ['は', '棄てざるは'], ['ば', '不徳ならば']]
# [['くらい', 'くらい'], ['を', 'わる口を']]
# [['は', '申し分は'], ['ば', '拝聴すれば']]
# [['に', 'ついでに']]
# [['に', 'たいていに']]
# [['が', '迷亭先生が'], ['と', '刻限だろうと']]
# [['が', '細君が'], ['と', '清やと'], ['を', '下女を']]
# [['が', '声が']]
# [['と', 'ものかと'], ['と', 'ウフフフフと'], ['ながら', '笑いながら'], ['は', '主人は']]
# [['を', '今のを']]
# [['の', '今の']]
# [['から', '説ですから']]
# [['で', '遠くで'], ['と', '存じませんと'], ['は', '妻君は'], ['を', '返事を']]
# [['と', 'くすくすと'], ['は', '寒月君は']]
# [['も', '私も']]
# [['んで', '存じませんで']]
# [['と', 'アハハハハと'], ['は', '迷亭君は']]
# [['を', '門口を']]
# [['て', 'あけて'], ['と', '笑ってると']]
# [['も', '御免とも']]
# [['が', '足音が']]
# [['と', 'したと']]
# [['が', '唐紙が'], ['に', '乱暴に']]
# [['から', 'その間から'], ['が', '顔が'], ['て', 'あいて'], ['とも', '頼むとも']]
# [['に', 'いつに'], ['は', '今日は']]
# [['に', 'シャツに'], ['を', 'フロックを']]
# [['か', '幾分か'], ['て', '着て'], ['を', '相場を']]
# [['に', '重そうに'], ['へ', '手へ']]
# [['へ', '上へ'], ['へ', '傍へ'], ['を', '麦酒を']]
# [['と', '置くと同時に'], ['も', '挨拶も']]
# [['を', '腰を']]
# [['て', '下ろしてかつ'], ['を', '膝を']]
# [['は', '崩したのは']]
# [['て', 'やって']]
# [['とも', '悪いとも']]
# [['から', '品川から'], ['を', '舟を']]
# [['て', '雇うて——'], ['に', '日曜に'], ['は', '私は']]
# [['か', '何か']]
# [['も', '何も']]
# [['を', '気を']]
# [['に', '釣に']]
# [['が', '事が']]
# [['て', '乗り廻わして'], ['で', '小舟で'], ['を', '上を']]
# [['と', 'あるくのですからねと']]
# [['で', '大船で'], ['を', '上を']]
# [['て', '乗り廻して'], ['は', '僕は']]
# [['が', '迷亭君が'], ['と', 'あるきたいんだと'], ['に', '相手に']]
# [['も', '人魚でも']]
# [['ちゃ', '釣らなくっちゃ']]
# [['が', '寒月君が'], ['と', '詰らないですと']]
# [['が', 'ものが']]
# [['に', 'ビジネスマンに']]
# [['に', '常識に'], ['は', '先生私は']]
# [['に', '所に']]
# [['から', '傍だから']]
# [['を', '敷島を']]
# [['が', '幅が'], ['ね', '煙草でもですね'], ['は', 'ふかしていては']]
# [['と', '利かんですと']]
# [['に', '吸口に'], ['の', '金箔の']]
# [['ながら', '云いながら'], ['を', '埃及煙草を']]
# [['て', '出して']]
# [['を', '贅沢を']]
# [['が', '金が']]
# [['が', 'なかばってんが'], ['は', '金は']]
# [['を', '煙草を']]
# [['が', '大変信用が'], ['と', '吸ってると']]
# [['を', '珠を']]
# [['が', '寒月君が'], ['で', '信用で'], ['も', '磨くよりも']]
# [['が', '手数が']]
# [['が', '迷亭が'], ['と', '軽便信用だねと'], ['に', '寒月に']]
# [['が', '寒月が']]
# [['が', 'あなたが'], ['に', '博士に']]
# [['が', '私が']]
# [['から', 'ものだから'], ['に', '事に']]
# [['と', '御気の毒と']]
# [['で', '先方で']]
# [['て', '是非貰うてくれ']]
# [['と', '貰うてくれと']]
# [['に', '事に']]
# [['と', 'わるいと']]
# [['て', '思って']]
# [['が', '寒月君が'], ['と', '遠慮なくと']]
# [['ば', '貰いたければ']]
# [['と', 'いいだろうと'], ['を', '返事を']]
# [['を', '娘を']]
# [['も', '持っても']]
# [['か', 'だれか']]
# [['が', '僕が']]
# [['が', '御聟さんが'], ['と', '貰うと']]
# [['が', '種が']]
# [['が', '迷亭君が'], ['と', 'とりかかりたまえと'], ['の', '例のごとく']]
# [['か', '何か'], ['か', '東風君ですか'], ['に', '時に']]
# [['に', '活版に']]
# [['て', 'して'], ['へ', '方々へ']]
# [['も', '太陽へも']]
# [['か', '何か']]
# [['でも', 'いつでも']]
# [['まで', '今まで']]
# [['でも', 'うちでも']]
# [['で', '呼んで']]
# [['を', 'シャンパンを']]
# [['を', '君シャンパンを']]
# [['が', '事が']]
# [['に', 'ときに'], ['を', '楽隊を']]
# [['に', '譜に'], ['を', '作を']]
# [['て', 'して']]
# [['に', '譜に']]
# [['て', 'して']]
# [['に', 'うちに'], ['の', '音楽の']]
# [['か', 'だれか'], ['は', 'ものは']]
# [['で', '頼んで']]
# [['じゃ', 'シャンパンくらいじゃ']]
# [['の', '私の']]
# [['が', '安いのじゃないですが'], ['を', '一つ譜を']]
# [['とも', '作りますとも'], ['も', 'シャンパンでも']]
# [['も', 'ただでも']]
# [['は', 'ただは']]
# [['は', '御礼は']]
# [['と', 'どうですと']]
# [['の', '上着の']]
# [['から', 'なかから'], ['を', '写真を']]
# [['て', '出して'], ['ながら', '云いながら'], ['へ', '上へ']]
# [['が', '半身が']]
# [['が', '全身が']]
# [['が', '立ってるのが']]
# [['が', '坐ってるのが']]
# [['を', '袴を']]
# [['が', '穿いてるが']]
# [['が', '振袖が']]
# [['が', '高島田が']]
# [['か', 'どれか'], ['に', '御礼に'], ['に', '東風君に']]
# [['と', 'どうですと'], ['につき', '一枚寒月君につき']]
# [['を', '是非周旋を']]
# [['でも', 'これでも']]
# [['と', 'いいですかと']]
# [['でも', 'どれでも']]
# [['が', '持参金が']]
# [['で', '一人で'], ['と', '娘ですと']]
# [['を', 'それを']]
# [['にゃ', '訳にゃ']]
# [['か', 'みんなですか'], ['は', 'それは']]
# [['と', 'よかろうと'], ['に', '叱りつけるように'], ['は', '主人は']]
# [['じゃ', 'それじゃ'], ['も', 'どれも']]
# [['と', '貰わんですねと'], ['を', '念を']]
# [['ながら', '押しながら'], ['に', '一枚に'], ['へ', 'ポッケットへ'], ['を', '写真を']]
# [['で', '酒屋で'], ['に', '前祝に']]
# [['って', '拍って'], ['を', '下女を'], ['を', '手を']]
# [['で', '呼んで'], ['は', '主人は'], ['を', '栓を']]
# [['を', 'コップを']]
# [['て', '捧げて'], ['は', '五君は'], ['を', '艶福を']]
# [['に', 'ここに']]
# [['に', '披露会に'], ['を', '諸君を']]
# [['か', '出てくれますか'], ['が', '招待しますが']]
# [['と', '出てくれるでしょうねと']]
# [['と', 'いやだと'], ['は', '主人は']]
# [['て', '出てくん']]
# [['が', '不人情じゃないが'], ['は', 'おれは']]
# [['くらい', '袴くらい'], ['でも', 'どうでも']]
# [['も', '人中へも']]
# [['に', '人に']]
# [['でも', '癒らんでも']]
# [['は', 'あなたは']]
# [['ね', '僕かね']]
# [['を', '栄を']]
# [['と', 'いらだろうと']]
# [['が', '仲人が']]
# [['も', '出来ても']]
# [['として', '人間として']]
# [['か', 'わからんですか']]
# [['は', '寒月君は']]
# [['も', '関係も']]
# [['に', '事に']]
# [['の', '僕の']]
# [['が', '楽隊が'], ['を', '曲を']]
# [['を', '奏するのを']]
# [['て', '出て'], ['で', '前で'], ['を', '新体詩を']]
# [['は', '私は']]
# [['を', '一杯ビールを']]
# [['で', '自分で'], ['と', '飲みますと']]
# [['で', '一人で'], ['を', 'ビールを']]
# [['で', '飲んで'], ['に', '真赤に']]
# [['は', '日は']]
# [['が', '死骸が'], ['を', '算を']]
# [['を', 'なかを']]
# [['て', '暮れて'], ['に', '昔に'], ['は', '火は'], ['ば', '見れば']]
# [['が', '興が'], ['も', '連中も']]
# [['と', '尽きたと']]
# [['て', '見えて']]
# [['が', '独仙君が'], ['と', '帰ろうかと']]
# [['も', '僕も']]
# [['て', 'つづいて'], ['と', '帰ると'], ['に', '口々に'], ['に', '玄関に']]
# [['が', '寄席が']]
# [['に', 'あとのように'], ['は', '座敷は']]
# [['を', '夕飯を']]
# [['て', 'すまして'], ['に', '書斎に'], ['は', '主人は']]
# [['を', '襟を']]
# [['て', 'かき合せて'], ['は', '妻君は'], ['を', '不断着を']]
# [['を', '枕を']]
# [['て', '並べて'], ['は', '小供は']]
# [['に', '湯に'], ['は', '下女は']]
# [['と', '呑気と']]
# [['を', '底を']]
# [['て', '叩いて'], ['も', '人々も']]
# [['が', '音が'], ['と', '見ると']]
# [['は', 'ほかは'], ['は', '足は'], ['も', '悟ったようでも']]
# [['に', '絵に']]
# [['を', '珠磨りを']]
# [['から', 'お国から'], ['て', 'やめて'], ['は', '寒月君は'], ['を', '奥さんを']]
# [['が', '順当が']]
# [['も', '東風君も']]
# [['を', '新体詩を']]
# [['を', '非を']]
# [['に', '三平君に']]
# [['に', '水に']]
# [['に', '山に']]
# [['を', '三鞭酒を']]
# [['と', '得意と']]
# [['が', '事が']]
# [['は', '藤さんは'], ['も', 'どこまでも']]
# [['が', '泥が'], ['ば', '転がれば']]
# [['が', '泥が']]
# [['も', 'ついても']]
# [['が', '幅が'], ['も', 'ものよりも']]
# [['と', '猫と']]
# [['て', '生れて'], ['に', '世に']]
# [['に', '二年越しに']]
# [['と', 'またと'], ['は', '自分では'], ['は', '見識家は']]
# [['と', 'あるまいと']]
# [['と', '先達てカーテル・ムルと']]
# [['が', '同族が'], ['を', '大気を']]
# [['が', '思うていたが'], ['ので', '揚げたので']]
# [['て', '聞いて']]
# [['に', '百年前に']]
# [['から', '好奇心から'], ['に', '幽霊に']]
# [['て', 'なって'], ['を', '吾輩を']]
# [['から', '冥土から'], ['が', '死んだのだが'], ['に', 'ために']]
# [['と', '母と'], ['を', '対面を']]
# [['として', 'しるしとして'], ['を', '肴を']]
# [['が', '我慢が'], ['で', '途中で']]
# [['て', 'し切れなくなって'], ['で', '自分で']]
# [['と', '食ってしまったと']]
# [['だけ', '不孝ものだけ']]
# [['に', '人間に'], ['も', '才気も']]
# [['を', '詩を']]
# [['て', '作って'], ['を', '主人を']]
# [['て', 'あって'], ['は', '時などは'], ['は', '猫は'], ['ほど', 'ほどで'], ['も', '事も']]
# [['が', '豪傑が'], ['に', '前に'], ['も', '一世紀も']]
# [['で', '碌で']]
# [['を', '御暇を']]
# [['て', '出現しているなら'], ['て', '頂戴して'], ['に', '無何有郷に'], ['は', 'なしは']]
# [['で', '胃病で'], ['は', '主人は']]
# [['で', '慾で'], ['は', 'じいさんは']]
# [['は', '木の葉は']]
# [['で', '定業で'], ['も', '生きていても']]
# [['が', '死ぬだけが']]
# [['に', '説に']]
# [['に', '自殺に'], ['は', '運命は'], ['ば', '従えば']]
# [['を', '油断を']]
# [['と', 'すると'], ['に', '世に'], ['も', '猫も']]
# [['が', '気が']]
# [['でも', 'ビールでも']]
# [['で', '飲んで'], ['を', '景気を']]
# [['へ', '勝手へ']]
# [['に', '秋風に']]
# [['が', '戸が'], ['に', '細目に']]
# [['から', '間から']]
# [['と', '吹き込んだと']]
# [['て', '見えて'], ['は', 'ランプは']]
# [['と', '月夜と']]
# [['から', '窓から'], ['が', '影が'], ['が', '消えているが'], ['て', '思われて']]
# [['が', 'コップが'], ['に', '上に']]
# [['が', '水が'], ['で', '並んで'], ['に', '二つに'], ['ほど', '半分ほど']]
# [['が', '気が'], ['は', 'ものは']]
# [['に', '月影に']]
# [['て', '照らされて'], ['と', '火消壺と'], ['に', '静かに']]
# [['を', '唇を']]
# [['から', '事だから'], ['から', '先から'], ['て', '寒くて']]
# [['を', 'あれを']]
# [['から', '飲んでから'], ['に', '真赤に']]
# [['て', 'なって'], ['は', '三平などは'], ['を', '息遣いを']]
# [['だって', '猫だって']]
# [['ば', '飲めば']]
# [['か', '死ぬか']]
# [['でも', '何でも'], ['の', '命の']]
# [['に', 'うちに']]
# [['から', '影から'], ['から', '死んでから'], ['と', '残念だと']]
# [['て', '思い切って']]
# [['で', '飲んで']]
# [['を', '舌を']]
# [['て', 'やって'], ['て', '入れて'], ['と', '見ろと']]
# [['と', '見ると']]
# [['で', '針で'], ['を', '先を']]
# [['で', '酔興で'], ['を', 'ものを']]
# [['か', '飲むのか'], ['は', '人間は']]
# [['が', 'わからないが'], ['は', '猫には']]
# [['が', '性が'], ['は', 'ビールは']]
# [['を', '舌を']]
# [['て', '引込めて'], ['と', '大変だと'], ['は', '一度は']]
# [['が', '見たがまた']]
# [['と', '苦しと']]
# [['て', '言って'], ['を', '風邪などを']]
# [['を', '顔を']]
# [['て', 'しかめて'], ['と', 'ひくと'], ['を', 'ものを']]
# [['か', '癒るのか'], ['のに', '癒るのに']]
# [['で', 'ビールで'], ['を', '問題を']]
# [['で', '飲んで'], ['まで', '腹の中まで']]
# [['に', '三平のように'], ['を', '前後を']]
# [['ほど', 'ほど']]
# [['で', '儲け者で'], ['ば', '愉快になれば'], ['へ', '猫へ']]
# [['か', 'なるか'], ['に', '天に'], ['を', '運を']]
# [['て', '任せて']]
# [['と', 'やっつけると']]
# [['て', '決心して'], ['を', '舌を']]
# [['を', '眼を']]
# [['と', 'あいていると']]
# [['から', '飲みにくいから']]
# [['て', '眠ってまた']]
# [['に', '我慢に'], ['を', '我慢を']]
# [['て', '重ねて'], ['を', 'ビールを']]
# [['が', '現象が'], ['は', '吾輩は']]
# [['が', '舌が']]
# [['から', '外部から'], ['が', '口中が'], ['て', 'ぴりぴりして']]
# [['に従って', '飲むに従って']]
# [['て', '楽になって'], ['を', '一杯目を']]
# [['が', '苦しかったのが'], ['は', '時分には'], ['も', '骨も']]
# [['は', '二杯目は']]
# [['に', 'ついでに'], ['に', '上に']]
# [['も', 'こぼれたのも']]
# [['が', '拭うがごとく'], ['に', '腹内に']]
# [['で', '自分で'], ['を', '動静を']]
# [['は', '間は']]
# [['が', '次第にからだが']]
# [['が', 'ふちが']]
# [['が', '耳が']]
# [['が', '歌が']]
# [['が', '猫じゃが'], ['じゃ', '猫じゃ']]
# [['も', '独仙も'], ['を', '糞を']]
# [['と', '食えと']]
# [['に', '気に']]
# [['を', 'じいさんを']]
# [['を', '鼻を']]
# [['と', 'ふらふらと'], ['に', '最後に']]
# [['は', 'こいつは'], ['へ', 'とそとへ']]
# [['と', '出ると'], ['と', '御月様今晩はと']]
# [['は', '陶然とは'], ['を', '事を']]
# [['と', '云うのだろうと']]
# [['と', 'かしこと']]
# [['ながら', '思いながら'], ['に', '加減に'], ['を', '足を']]
# [['か', '寝ているのだか']]
# [['か', 'あるいてるのだか']]
# [['は', '眼は']]
# [['が', '海だろうが'], ['と', '驚ろかないんだと'], ['へ', 'ぐにゃりと前へ'], ['を', '前足を']]
# [['と', '出したと']]
# [['が', '音が']]
# [['て', 'して']]
# [['か', 'やられたのか']]
# [['と', 'やられたなと']]
# [['か', '気がつくか'], ['のに', 'つかないのに'], ['は', 'あとは']]
# [['に', '我に']]
# [['に', '水の上に'], ['は', 'ときは']]
# [['で', '爪で']]
# [['から', '苦しいから'], ['て', 'もって'], ['に', '矢鱈に']]
# [['が', '掻いたが'], ['と', '掻くと'], ['ばかり', '水ばかりで']]
# [['から', 'ないから'], ['で', '後足で']]
# [['て', '飛び上っておいて'], ['で', '前足で']]
# [['が', '音が'], ['と', '掻いたらがりりと']]
# [['が', '手応が'], ['て', 'して'], ['に', 'わずかに']]
# [['だけ', '頭だけ']]
# [['から', '浮くから'], ['と', 'どこだろうと']]
# [['と', '見廻わすと'], ['に', '中に'], ['は', '吾輩は']]
# [['と', '水葵と'], ['まで', '夏まで']]
# [['が', '水草が']]
# [['が', '勘公が']]
# [['て', '来て'], ['を', '葵を']]
# [['が', '茂っていたが'], ['に', '上に'], ['は', '甕は'], ['を', '行水を']]
# [['を', '行水を']]
# [['が', '水が'], ['ば', '使えば']]
# [['が', '烏が'], ['って', '大分減って']]
# [['と', '見えないなと'], ['は', '近来は']]
# [['が', '吾輩自身が'], ['で', '所で'], ['に', '代りに'], ['を', '行水を']]
# [['が', '思ったが'], ['は', '使おうなどとは'], ['も', '思いも']]
# [['から', '水から'], ['は', '縁までは'], ['も', '四寸余も']]
# [['を', '足を']]
# [['も', 'のばしても']]
# [['も', '飛び上っても']]
# [['ば', '呑気にしていれば']]
# [['が', '爪が'], ['と', 'がりがりと'], ['に', '甕に'], ['ば', 'もがけば']]
# [['が', '気味だが'], ['のみ', 'あたるのみで'], ['ば', 'すべれば']]
# [['から', '苦しいから'], ['を', 'がりがりを']]
# [['が', 'うちからだが']]
# [['は', '気は']]
# [['が', '焦るが'], ['は', '足は']]
# [['に', 'ために'], ['を', '甕を']]
# [['か', '掻くのか'], ['に', 'ために']]
# [['か', 'もぐるのか'], ['は', 'ついには'], ['も', '自分でも']]
# [['ながら', '苦しいながら']]
# [['に', '呵責に']]
# [['から', '甕から'], ['へ', '上へ']]
# [['が', '山々であるが'], ['は', '上がれないのは']]
# [['に', '三寸に'], ['は', '足は']]
# [['が', '面にからだが']]
# [['から', '所から'], ['を', '前足を']]
# [['って', 'のばしたって'], ['に', '五寸に']]
# [['の', '爪の']]
# [['の', '爪の']]
# [['も', 'いくらも']]
# [['ば', 'なければ'], ['も', '掻いても']]
# [['に', '粉に'], ['も', 'あせっても'], ['を', '間身を']]
# [['も', 'しても']]
# [['と', '出られないと']]
# [['を', 'ものを']]
# [['を', '無理を']]
# [['て', '求めて']]
# [['で', '好んで'], ['で', '苦しんで'], ['に', '拷問に']]
# [['は', '罹っているのは']]
# [['は', 'がりがりは']]
# [['に', '力に']]
# [['て', '任せて'], ['も', '尾も']]
# [['と', '蒙るよと'], ['に', '事に']]
# [['か', 'ありがたいのだか'], ['が', '見当が']]
# [['に', '中に']]
# [['か', 'いるのだか'], ['に', '上に']]
# [['か', 'いるのだか']]
# [['に', 'どこに']]
# [['も', '楽そのものすらも']]
# [['を', '日月を']]
# [['を', '天地を']]
# [['て', '粉韲して'], ['に', '太平に']]
# [['は', '吾輩は']]
# [['で', '死んで'], ['を', '太平を']]
# [['は', '太平は'], ['ば', '死ななければ']]
