# %% [markdown]
# スペースで区切られた単語列に対して，各単語の先頭と末尾の文字は残し，それ以外の文字の順序をランダムに並び替えるプログラムを作成せよ．ただし，長さが４以下の単語は並び替えないこととする．適当な英語の文（例えば"I couldn't believe that I could actually understand what I was reading : the phenomenal power of the human mind ."）を与え，その実行結果を確認せよ．

# %%
import random

def typoglycemia(sentense):
    word_list = sentense.split()
    
    # 最後のピリオドが最終単語と離れている場合は結合
    if word_list[len(word_list) - 1] == '.':
        word_list[len(word_list) - 2] = word_list[len(word_list) - 2] + '.'
        del word_list[len(word_list) - 1]
    
    result = []
    random_word = []
    
    for i, word in enumerate(word_list):
        # 最初と最後、および4文字以下の単語を固定
        if  i == 0\
         or i == len(word_list) - 1\
         or len(word) <= 4:
            result.append(word)

        # ランダムに並び替える単語の配列作成
        else:
            result.append('')
            random_word.append(word)
    
    # ブランク箇所をランダムに挿入
    for i, word in enumerate(result):
        if word == '':
            del_num = random.randrange(len(random_word))
            result[i] = random_word[del_num]
            del random_word[del_num]
    
    return ' '.join(result)

# %%
print(typoglycemia('I couldn\'t believe that I could actually understand what I was reading : the phenomenal power of the human mind.'))
# Out:
# ['I', "couldn't", 'believe', 'that', 'I', 'could', 'actually', 'understand', 'what', 'I', 'was', 'reading', ':', 'the', 'phenomenal', 'power', 'of', 'the', 'human', 'mind.']
# I phenomenal human that I could understand actually what I was believe : the power reading of the couldn't mind.
