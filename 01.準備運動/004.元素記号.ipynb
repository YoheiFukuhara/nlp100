# %% [markdown]
# "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."という文を単語に分解し，1, 5, 6, 7, 8, 9, 15, 16, 19番目の単語は先頭の1文字，それ以外の単語は先頭に2文字を取り出し，取り出した文字列から単語の位置（先頭から何番目の単語か）への連想配列（辞書型もしくはマップ型）を作成せよ．

# %%
sentense = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'

# %%
word_list = sentense.split()
print(word_list)
# Out:
# ['Hi', 'He', 'Lied', 'Because', 'Boron', 'Could', 'Not', 'Oxidize', 'Fluorine.', 'New', 'Nations', 'Might', 'Also', 'Sign', 'Peace', 'Security', 'Clause.', 'Arthur', 'King', 'Can.']

# %%
dict = {}
for i, word in enumerate(word_list):
    if  i == 0 \
     or i == 4 \
     or i == 5 \
     or i == 6 \
     or i == 7 \
     or i == 8 \
     or i == 14 \
     or i == 15 \
     or i == 18:
        dict[word[0]] = i + 1
    else:
        dict[word[0:2:]] = i + 1
        
print(dict)
# Out:
# {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10, 'Na': 11, 'Mi': 12, 'Al': 13, 'Si': 14, 'P': 15, 'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20}

# %%
# Out:
# {'Hi': 0, 'He': 1, 'Lied': 2, 'Because': 3, 'Boron': 4, 'Could': 5, 'Not': 6, 'Oxidize': 7, 'Fluorine.': 8, 'New': 9, 'Nations': 10, 'Might': 11, 'Also': 12, 'Sign': 13, 'Peace': 14, 'Security': 15, 'Clause.': 16, 'Arthur': 17, 'King': 18, 'Can.': 19}
