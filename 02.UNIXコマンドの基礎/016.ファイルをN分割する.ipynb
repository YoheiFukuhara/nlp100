# %% [markdown]
# 自然数Nをコマンドライン引数などの手段で受け取り，入力のファイルを行単位でN分割せよ．同様の処理をsplitコマンドで実現せよ．

# %%
from google.colab import files
import pandas as pd
import io
import argparse

# %%
FLAGS = None
def main():
    uploaded = files.upload()
    df = pd.read_table(io.StringIO(uploaded['hightemp.txt'].decode('utf-8')), header=None)
    
    #Pythonで切り上げは面倒
    num_split = -(len(df.index) // (-1 * FLAGS.split) )
    
    for i in range(num_split):
        #最終行は少し範囲が多すぎることがあるが気にしない
        print(df[i * FLAGS.split:(i + 1) * FLAGS.split])

# %%
if __name__ == '__main__':
    parser = argparse.ArgumentParser()
    parser.add_argument(
        '--split',
        type=int,
        default=5,
        help='Number of split into files'
    )
FLAGS, unparsed = parser.parse_known_args()
main()
# Out:
#      <input type="file" id="files-34195533-bb67-4273-ad2a-c7274dc3336c" name="files[]" multiple disabled />
#      <output id="result-34195533-bb67-4273-ad2a-c7274dc3336c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hightemp.txt to hightemp (18).txt
#      0    1     2           3
# 0  高知県  江川崎  41.0  2013-08-12
# 1  埼玉県   熊谷  40.9  2007-08-16
# 2  岐阜県  多治見  40.9  2007-08-16
# 3  山形県   山形  40.8  1933-07-25
# 4  山梨県   甲府  40.7  2013-08-10
#       0     1     2           3
# 5  和歌山県  かつらぎ  40.6  1994-08-08
# 6   静岡県    天竜  40.6  1994-08-04
# 7   山梨県    勝沼  40.5  2013-08-10
# 8   埼玉県    越谷  40.4  2007-08-16
# 9   群馬県    館林  40.3  2007-08-16
#       0    1     2           3
# 10  群馬県  上里見  40.3  1998-07-04
# 11  愛知県   愛西  40.3  1994-08-05
# 12  千葉県   牛久  40.2  2004-07-20
# ...
