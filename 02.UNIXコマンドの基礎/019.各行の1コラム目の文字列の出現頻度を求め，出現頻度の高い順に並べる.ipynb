# %% [markdown]
# 各行の1列目の文字列の出現頻度を求め，その高い順に並べて表示せよ．確認にはcut, uniq, sortコマンドを用いよ．

# %%
from google.colab import files
import pandas as pd
import io

# %%
uploaded = files.upload()
df = pd.read_table(io.StringIO(uploaded['hightemp.txt'].decode('utf-8')), header=None)
# Out:
#      <input type="file" id="files-edf9174b-257d-452d-a060-9348343cac25" name="files[]" multiple disabled />
#      <output id="result-edf9174b-257d-452d-a060-9348343cac25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hightemp.txt to hightemp.txt

# %%
print(df[0].value_counts(ascending=False))
# Out:
# 山形県     3
# 群馬県     3
# 埼玉県     3
# 山梨県     3
# 愛知県     2
# 静岡県     2
# 岐阜県     2
# 千葉県     2
# 愛媛県     1
# 大阪府     1
# 和歌山県    1
# 高知県     1
# Name: 0, dtype: int64
